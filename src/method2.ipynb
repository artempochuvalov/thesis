# %%
from typing import Callable, Tuple

import numpy as np
import pandas as pd
from numba import prange, njit, typed, types
from tqdm.notebook import trange
from numpy.typing import NDArray
from numba import njit, prange
import matplotlib.pyplot as plt
from scipy import stats
from sklearn import preprocessing

# %%
def get_service_times() -> NDArray['float']:
    df = pd.read_csv('../data/service_times.csv')
    df.rename(columns={'TTI 0.95': 'service_time' }, inplace=True)
    df['service_time'] = df['service_time'].map(lambda time: float(time.replace('ms', '')))

    return np.array(df['service_time'])

# %%
service_times = get_service_times()

# %%
@njit
def arrive_cdf(n: int) -> float:
    return np.random.exponential(0.299 * n)
    
@njit
def leave_cdf() -> float:
    return np.random.exponential(510)

@njit
def departure_cdf() -> float:
    return np.random.choice(service_times) * 0.95 / 4

# %%
@njit
def get_next_event(
    arrival_time: float,
    request_times_queue: list,
    departure_time: float,
) -> (float, str, int):
    event_type = 'ARRIVAL'
    min_index = -1
    min_time = arrival_time

    if departure_time != -1 and departure_time < min_time:
        event_type = 'DEPARTURE'
        min_time = departure_time

    min_leave_time_index = -1
    min_leave_time = np.inf
    if len(request_times_queue) != 0:
        min_leave_time_index = np.argmin(request_times_queue)
    if min_leave_time_index != -1:
        min_leave_time = request_times_queue[min_leave_time_index]
        
    if min_leave_time < min_time:
        min_index = min_leave_time_index
        min_time = min_leave_time
        event_type = 'LEAVE'

    return min_time, event_type, min_index

# %%
@njit
def arrival(
    time: float,
    num_in_system: int,
    num_total_requests: int,
    leave_indicator: int,
    request_times_queue: list,
    departure_time: float,
    n: int,
    N: int,
) -> (float, int, int, int, list, float):
    num_in_system += 1 # увеличиваем число запросов в системе
    num_total_requests += 1

    if departure_time == -1: # если сервер свободен
        mu = departure_cdf()
        departure_time = time
        departure_time = time + mu # планируем обработку запроса
    else:
        if len(request_times_queue) == N:
            num_in_system -= 1 # считаем, что заявка покинула систему
            leave_indicator += 1 # увеличиваем индикатор выхода из системы
        else:
            gamma = leave_cdf()
            request_times_queue = np.append(request_times_queue, time + gamma)
    
    alpha = arrive_cdf(n)
    time += alpha
    return time, num_in_system, num_total_requests, leave_indicator, request_times_queue, departure_time

@njit
def departure(
    time: float,
    num_in_system: int,
    request_times_queue: list,
    departure_time: float,
) -> (int, list, list):
    num_in_system -= 1 # запрос обработан - уменьшаем число запросов в системе
    
    if (len(request_times_queue) == 0): # если очередь пуста
        departure_time = -1
    else:        
        gamma = departure_cdf()
        departure_time = time + gamma # планируем обработку запроса
        request_times_queue = np.delete(request_times_queue, 0)
    return num_in_system, request_times_queue, departure_time

@njit
def on_leave(
    time_index: float,
    num_in_system: int,
    leave_indicator: int,
    request_times_queue: list
) -> (int, int, list):
    num_in_system -= 1 # запрос ушёл - уменьшаем число запросов в системе
    leave_indicator += 1 # увеличиваем индикатор выхода из системы
    
    request_times_queue = np.delete(request_times_queue, time_index)

    return num_in_system, leave_indicator, request_times_queue

# %%
@njit
def update_area_num_in_system_stat(
    time: float,
    past_event_time: float,
    num_in_system: int,
    area_num_in_system: float
) -> (float, float):
    time_since_past_event = time - past_event_time
    past_event_time = time

    area_num_in_system += (num_in_system * time_since_past_event)
    return past_event_time, area_num_in_system

# %%
@njit
def num_in_system_iteration(
    T: float,
    n: int,
    N: int,
    return_value: str = 'average_requests_in_system'
) -> float:
    time = 0.0
    past_event_time = 0.0

    num_in_system = 0
    area_num_in_system: float = 0.0

    num_total_requests = 0
    leave_indicator = 0
    
    arrival_time = arrive_cdf(n)
    leave = leave_cdf()

    departure_time = -1
    request_times_queue = np.empty(0, dtype=np.float64)
    
    while time < T:
        time, event_type, time_index = get_next_event(arrival_time, request_times_queue, departure_time)
        past_event_time, area_num_in_system = update_area_num_in_system_stat(
            time,
            past_event_time,
            num_in_system,
            area_num_in_system
        )
        
        if event_type == 'ARRIVAL':
            arrival_time, num_in_system, num_total_requests, leave_indicator, request_times_queue, departure_time = arrival(
                time,
                num_in_system,
                num_total_requests,
                leave_indicator,
                request_times_queue,
                departure_time,
                n,
                N
            )
        elif event_type == 'DEPARTURE':
            num_in_system, request_times_queue, departure_time = departure(
                time,
                num_in_system,
                request_times_queue,
                departure_time
            )
        else:
            num_in_system, leave_indicator, request_times_queue = on_leave(
                time_index,
                num_in_system,
                leave_indicator,
                request_times_queue
            )

    average_requests_in_system = area_num_in_system / time
    loss_probability = leave_indicator / num_total_requests

    if return_value == 'average_requests_in_system':
        return average_requests_in_system
    if return_value == 'loss_probability':
        return loss_probability

# %%
@njit(parallel=True)
def num_in_system_iteration_resolver(
    T: float,
    N: int,
    n: int,
    max_queue_size: int,
    x_betta: float,
    eps: float = 1e-3,
    return_value: str = 'average_requests_in_system'
) -> float:
    N_new = N
    N_old = 0

    sum_data = 0
    sum_data_sq = 0
    while True: 
        for i in prange(N - N_old):
            value = num_in_system_iteration(T, n, max_queue_size, return_value)
            sum_data += value
            sum_data_sq += value ** 2
        E = sum_data / N
        D = (sum_data_sq / N) - (E ** 2)
        N_new = int(((x_betta ** 2) * D) / (eps ** 2))

        if N_new <= N:
            return E
        N_old = N
        N = N_new
        
        print(f'New N: {N}, old N: {N_old}')

# %%
MAX_SERVERS = 200
MIN_SERVERS = 1

servers_num = np.arange(MIN_SERVERS, MAX_SERVERS + 1)
loss_probabilities = np.empty(0)

T = 10000
iterations = 1000
max_queue_size = 10_000
eps = 1e-3
betta = 0.95
x_betta = stats.norm.ppf(betta)

for i in trange(MIN_SERVERS, MAX_SERVERS + 1):    
    loss_probability = num_in_system_iteration_resolver(
        T,
        iterations,
        i,
        max_queue_size,
        x_betta=x_betta,
        eps=eps,
        return_value = 'loss_probability'
    )
    print(f'Probability of loss: {loss_probability} for servers number: {i}')
    loss_probabilities = np.append(loss_probabilities, loss_probability)

with open('./random/loss_probabilities.npy', 'wb') as f:
    np.save(f, loss_probabilities)
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
# Probability of loss: 0.9410563691601381 for servers number: 1
# Probability of loss: 0.9331633715710242 for servers number: 2
# Probability of loss: 0.9250940037351248 for servers number: 3
# Probability of loss: 0.9172012592533286 for servers number: 4
# Probability of loss: 0.9094423330656657 for servers number: 5
# Probability of loss: 0.9012251802583129 for servers number: 6
# Probability of loss: 0.8934036381606578 for servers number: 7
# Probability of loss: 0.8855301815278396 for servers number: 8
# Probability of loss: 0.8774535603181811 for servers number: 9
# Probability of loss: 0.8696105046209925 for servers number: 10
# Probability of loss: 0.8616151947814222 for servers number: 11
# Probability of loss: 0.853715626139067 for servers number: 12
# Probability of loss: 0.8455660227326901 for servers number: 13
# Probability of loss: 0.8374148187461525 for servers number: 14
# Probability of loss: 0.8298144411110125 for servers number: 15
# Probability of loss: 0.8218809930223232 for servers number: 16
# Probability of loss: 0.8141648977742939 for servers number: 17
# Probability of loss: 0.8061801955280716 for servers number: 18
# Probability of loss: 0.7982720038656888 for servers number: 19
# Probability of loss: 0.790009413442495 for servers number: 20
# Probability of loss: 0.7823929048687837 for servers number: 21
# Probability of loss: 0.7745466341323256 for servers number: 22
# Probability of loss: 0.7664441258886938 for servers number: 23
# Probability of loss: 0.7586340658719826 for servers number: 24
# Probability of loss: 0.7503611382120731 for servers number: 25
# Probability of loss: 0.742750510108694 for servers number: 26
# Probability of loss: 0.7349320423863441 for servers number: 27
# Probability of loss: 0.7272173300290694 for servers number: 28
# Probability of loss: 0.7190808067393875 for servers number: 29
# Probability of loss: 0.7114208651534466 for servers number: 30
# Probability of loss: 0.7027921787968741 for servers number: 31
# Probability of loss: 0.6947601123373923 for servers number: 32
# Probability of loss: 0.6864143715970177 for servers number: 33
# Probability of loss: 0.6795042283051136 for servers number: 34
# Probability of loss: 0.6707907828960773 for servers number: 35
# Probability of loss: 0.663479632794734 for servers number: 36
# Probability of loss: 0.6559478692199282 for servers number: 37
# Probability of loss: 0.6479710944028656 for servers number: 38
# Probability of loss: 0.6396989387116401 for servers number: 39
# Probability of loss: 0.6312789393377866 for servers number: 40
# Probability of loss: 0.6238148348366215 for servers number: 41
# Probability of loss: 0.6155834914443091 for servers number: 42
# Probability of loss: 0.6082720637161138 for servers number: 43
# Probability of loss: 0.5983189268401939 for servers number: 44
# Probability of loss: 0.592130863661816 for servers number: 45
# Probability of loss: 0.5836840121043693 for servers number: 46
# Probability of loss: 0.5758520096046051 for servers number: 47
# Probability of loss: 0.5681665748198668 for servers number: 48
# Probability of loss: 0.5604360314042329 for servers number: 49
# Probability of loss: 0.5520463084815954 for servers number: 50
# Probability of loss: 0.5445818650514344 for servers number: 51
# Probability of loss: 0.5361481153286403 for servers number: 52
# Probability of loss: 0.5278457878372198 for servers number: 53
# New N: 1002, old N: 1000
# Probability of loss: 0.5193185638863995 for servers number: 54
# New N: 1005, old N: 1000
# New N: 1006, old N: 1005
# New N: 1009, old N: 1006
# Probability of loss: 0.511863475546243 for servers number: 55
# New N: 1094, old N: 1000
# Probability of loss: 0.5053143172963545 for servers number: 56
# New N: 1137, old N: 1000
# New N: 1189, old N: 1137
# New N: 1198, old N: 1189
# Probability of loss: 0.4974949301912369 for servers number: 57
# New N: 1278, old N: 1000
# New N: 1308, old N: 1278
# New N: 1314, old N: 1308
# New N: 1759, old N: 1000
# Probability of loss: 0.13259489118519463 for servers number: 117
# New N: 1767, old N: 1000
# New N: 1805, old N: 1767
# New N: 1812, old N: 1805
# Probability of loss: 0.12948347637161362 for servers number: 118
# New N: 1758, old N: 1000
# Probability of loss: 0.12740218464994973 for servers number: 119
# New N: 1638, old N: 1000
# New N: 1718, old N: 1638
# Probability of loss: 0.1243002283750602 for servers number: 120
# New N: 1545, old N: 1000
# New N: 1569, old N: 1545
# Probability of loss: 0.12188744999711801 for servers number: 121
# New N: 1554, old N: 1000
# New N: 1586, old N: 1554
# Probability of loss: 0.11940909543240233 for servers number: 122
# New N: 1676, old N: 1000
# Probability of loss: 0.11682400120516535 for servers number: 123
# New N: 1529, old N: 1000
# New N: 1592, old N: 1529
# New N: 1596, old N: 1592
# Probability of loss: 0.11495887370123935 for servers number: 124
# New N: 1465, old N: 1000
# New N: 1467, old N: 1465
# Probability of loss: 0.11156487380349858 for servers number: 125
# New N: 1457, old N: 1000
# New N: 1474, old N: 1457
# New N: 1481, old N: 1474
# Probability of loss: 0.11004919206541305 for servers number: 126
# New N: 1516, old N: 1000
# Probability of loss: 0.10802424018965395 for servers number: 127
# New N: 1467, old N: 1000
# New N: 1493, old N: 1467
# New N: 1494, old N: 1493
# Probability of loss: 0.10537999277842232 for servers number: 128
# New N: 1400, old N: 1000
# New N: 1438, old N: 1400
# Probability of loss: 0.10433214008347345 for servers number: 129
# New N: 1334, old N: 1000
# Probability of loss: 0.10131715584282963 for servers number: 130
# New N: 1324, old N: 1000
# New N: 1334, old N: 1324
# Probability of loss: 0.1003507163385759 for servers number: 131
# New N: 1373, old N: 1000
# Probability of loss: 0.09893321752465774 for servers number: 132
# New N: 1357, old N: 1000
# Probability of loss: 0.09653836207886701 for servers number: 133
# New N: 1300, old N: 1000
# New N: 1339, old N: 1300
# Probability of loss: 0.09429626496272195 for servers number: 134
# New N: 1163, old N: 1000
# New N: 1166, old N: 1163
# Probability of loss: 0.09277516191638534 for servers number: 135
# New N: 1316, old N: 1000
# New N: 1325, old N: 1316
# Probability of loss: 0.09104632542674966 for servers number: 136
# New N: 1285, old N: 1000
# New N: 1311, old N: 1285
# New N: 1316, old N: 1311
# New N: 1317, old N: 1316
# Probability of loss: 0.08976103307874568 for servers number: 137
# New N: 1247, old N: 1000
# Probability of loss: 0.08747543965998276 for servers number: 138
# New N: 1234, old N: 1000
# Probability of loss: 0.08591684987218817 for servers number: 139
# New N: 1106, old N: 1000
# Probability of loss: 0.08556182841504252 for servers number: 140
# New N: 1124, old N: 1000
# New N: 1137, old N: 1124
# Probability of loss: 0.08312006342556698 for servers number: 141
# New N: 1160, old N: 1000
# Probability of loss: 0.08212275938808095 for servers number: 142
# New N: 1099, old N: 1000
# New N: 1127, old N: 1099
# Probability of loss: 0.0821863493987992 for servers number: 143
# New N: 1100, old N: 1000
# New N: 1133, old N: 1100
# Probability of loss: 0.07962786200818074 for servers number: 144
# New N: 1053, old N: 1000
# Probability of loss: 0.07994516434853517 for servers number: 145
# Probability of loss: 0.04058452941002059 for servers number: 198
# Probability of loss: 0.04126790810101728 for servers number: 199
# Probability of loss: 0.04013652295486979 for servers number: 200

# %%
MAX_SERVERS = 200
MIN_SERVERS = 1

servers_num = np.arange(MIN_SERVERS, MAX_SERVERS + 1)
requests_in_system_list = np.empty(0)

T = 10000
iterations = 1000
max_queue_size = 10_000
eps = 1e-0
betta = 0.95
x_betta = stats.norm.ppf(betta)

for i in trange(MIN_SERVERS, MAX_SERVERS + 1):    
    avarege_requests_in_system = num_in_system_iteration_resolver(
        T,
        iterations,
        i,
        max_queue_size,
        x_betta=x_betta,
        eps=eps,
        return_value = 'average_requests_in_system'
    )
    print(f'Avarege requests in system: {avarege_requests_in_system} for servers number: {i}')
    requests_in_system_list = np.append(requests_in_system_list, avarege_requests_in_system)

with open('./random/requests_in_system_list.npy', 'wb') as f:
    np.save(f, requests_in_system_list)
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
# Avarege requests in system: 1605.69255554138 for servers number: 1
# Avarege requests in system: 797.1899403055669 for servers number: 2
# Avarege requests in system: 527.1349822345767 for servers number: 3
# Avarege requests in system: 391.6252268685813 for servers number: 4
# Avarege requests in system: 311.33802712866367 for servers number: 5
# Avarege requests in system: 257.1539348497691 for servers number: 6
# Avarege requests in system: 218.72540563892818 for servers number: 7
# Avarege requests in system: 189.8031727747713 for servers number: 8
# Avarege requests in system: 167.10114807007253 for servers number: 9
# Avarege requests in system: 149.35245161303217 for servers number: 10
# Avarege requests in system: 134.54127538649195 for servers number: 11
# Avarege requests in system: 122.35779768293392 for servers number: 12
# Avarege requests in system: 111.64373533153251 for servers number: 13
# Avarege requests in system: 102.97996263754608 for servers number: 14
# Avarege requests in system: 95.32036508934645 for servers number: 15
# Avarege requests in system: 88.54787608125702 for servers number: 16
# Avarege requests in system: 82.86889458195279 for servers number: 17
# Avarege requests in system: 77.42386005156803 for servers number: 18
# Avarege requests in system: 72.56233176715288 for servers number: 19
# Avarege requests in system: 68.45743734527184 for servers number: 20
# Avarege requests in system: 64.51958707969361 for servers number: 21
# Avarege requests in system: 61.11883362305 for servers number: 22
# Avarege requests in system: 57.83120645455712 for servers number: 23
# Avarege requests in system: 55.007545635259234 for servers number: 24
# Avarege requests in system: 52.14951830067571 for servers number: 25
# Avarege requests in system: 49.57961249865277 for servers number: 26
# Avarege requests in system: 47.46871129129155 for servers number: 27
# Avarege requests in system: 45.203140995170735 for servers number: 28
# Avarege requests in system: 43.30433505906217 for servers number: 29
# Avarege requests in system: 41.47764963912401 for servers number: 30
# Avarege requests in system: 39.83708376876712 for servers number: 31
# Avarege requests in system: 37.92801758169302 for servers number: 32
# Avarege requests in system: 36.69183817596606 for servers number: 33
# Avarege requests in system: 35.13576300512711 for servers number: 34
# Avarege requests in system: 33.62075221974386 for servers number: 35
# Avarege requests in system: 32.42670251716475 for servers number: 36
# Avarege requests in system: 31.16189729435922 for servers number: 37
# Avarege requests in system: 29.96497861395876 for servers number: 38
# Avarege requests in system: 28.985136453332235 for servers number: 39
# Avarege requests in system: 28.009439557374698 for servers number: 40
# Avarege requests in system: 26.896711725299735 for servers number: 41
# Avarege requests in system: 25.952121690101894 for servers number: 42
# Avarege requests in system: 25.07136267146881 for servers number: 43
# Avarege requests in system: 24.366557942652186 for servers number: 44
# Avarege requests in system: 23.42711902469353 for servers number: 45
# Avarege requests in system: 22.67202235835797 for servers number: 46
# Avarege requests in system: 21.862149346829238 for servers number: 47
# Avarege requests in system: 21.134387405452678 for servers number: 48
# Avarege requests in system: 20.52599230271433 for servers number: 49
# Avarege requests in system: 19.934443211331402 for servers number: 50
# Avarege requests in system: 19.200426201734853 for servers number: 51
# Avarege requests in system: 18.59992841324388 for servers number: 52
# Avarege requests in system: 17.961990705438645 for servers number: 53
# Avarege requests in system: 17.432463615680025 for servers number: 54
# Avarege requests in system: 17.00795131064512 for servers number: 55
# Avarege requests in system: 16.353257028501954 for servers number: 56
# Avarege requests in system: 15.82010955950465 for servers number: 57
# Avarege requests in system: 15.415805245568647 for servers number: 58
# Avarege requests in system: 14.929413462803227 for servers number: 59
# Avarege requests in system: 14.500903302561005 for servers number: 60
# Avarege requests in system: 14.094684995188153 for servers number: 61
# Avarege requests in system: 13.503317367357162 for servers number: 62
# Avarege requests in system: 13.195567006315695 for servers number: 63
# Avarege requests in system: 12.80099829849336 for servers number: 64
# Avarege requests in system: 12.389096026413792 for servers number: 65
# Avarege requests in system: 12.015491037154796 for servers number: 66
# Avarege requests in system: 11.683292812755445 for servers number: 67
# Avarege requests in system: 11.34757308586117 for servers number: 68
# Avarege requests in system: 10.950471533835861 for servers number: 69
# Avarege requests in system: 10.60933698479319 for servers number: 70
# Avarege requests in system: 10.316129615755719 for servers number: 71
# Avarege requests in system: 10.047285624199711 for servers number: 72
# Avarege requests in system: 9.732750006638078 for servers number: 73
# Avarege requests in system: 9.384744700729382 for servers number: 74
# Avarege requests in system: 9.194696270988683 for servers number: 75
# Avarege requests in system: 8.91195660881949 for servers number: 76
# Avarege requests in system: 8.550950469835858 for servers number: 77
# Avarege requests in system: 8.328081460961611 for servers number: 78
# Avarege requests in system: 8.071436517615815 for servers number: 79
# Avarege requests in system: 7.856752212032473 for servers number: 80
# Avarege requests in system: 7.552901062307121 for servers number: 81
# Avarege requests in system: 7.32012095901266 for servers number: 82
# Avarege requests in system: 7.138058674792809 for servers number: 83
# Avarege requests in system: 6.905196352557998 for servers number: 84
# Avarege requests in system: 6.748570735978434 for servers number: 85
# Avarege requests in system: 6.520211853863178 for servers number: 86
# Avarege requests in system: 6.272928579038771 for servers number: 87
# Avarege requests in system: 6.120311492667564 for servers number: 88
# Avarege requests in system: 5.946888247039022 for servers number: 89
# Avarege requests in system: 5.766822570370087 for servers number: 90
# Avarege requests in system: 5.688119456655585 for servers number: 91
# Avarege requests in system: 5.473628371705887 for servers number: 92
# Avarege requests in system: 5.279319645795084 for servers number: 93
# Avarege requests in system: 5.134718199746017 for servers number: 94
# Avarege requests in system: 4.961324920589532 for servers number: 95
# Avarege requests in system: 4.795433360486411 for servers number: 96
# Avarege requests in system: 4.676472282086032 for servers number: 97
# Avarege requests in system: 4.567589590443166 for servers number: 98
# Avarege requests in system: 4.470767648930092 for servers number: 99
# Avarege requests in system: 4.355253223168971 for servers number: 100
# Avarege requests in system: 4.207767058460418 for servers number: 101
# Avarege requests in system: 4.097542570273392 for servers number: 102
# Avarege requests in system: 3.9743349343444354 for servers number: 103
# Avarege requests in system: 3.8765154320358732 for servers number: 104
# Avarege requests in system: 3.7830581798528646 for servers number: 105
# Avarege requests in system: 3.6727644735803944 for servers number: 106
# Avarege requests in system: 3.5747779871328462 for servers number: 107
# Avarege requests in system: 3.4841047784023766 for servers number: 108
# Avarege requests in system: 3.430047408501385 for servers number: 109
# Avarege requests in system: 3.3207728874268887 for servers number: 110
# Avarege requests in system: 3.2190965656995854 for servers number: 111
# Avarege requests in system: 3.184947756899998 for servers number: 112
# Avarege requests in system: 3.0592731220321756 for servers number: 113
# Avarege requests in system: 3.020840962582357 for servers number: 114
# Avarege requests in system: 2.9444753569434714 for servers number: 115
# Avarege requests in system: 2.8696705297247163 for servers number: 116
# Avarege requests in system: 2.8359874712129898 for servers number: 117
# Avarege requests in system: 2.785749068338754 for servers number: 118
# Avarege requests in system: 2.6861508959044067 for servers number: 119
# Avarege requests in system: 2.621312918430542 for servers number: 120
# Avarege requests in system: 2.5861712313138385 for servers number: 121
# Avarege requests in system: 2.5173129281900364 for servers number: 122
# Avarege requests in system: 2.4836103855917155 for servers number: 123
# Avarege requests in system: 2.4397144644395654 for servers number: 124
# Avarege requests in system: 2.3778844742680607 for servers number: 125
# Avarege requests in system: 2.3327384742135733 for servers number: 126
# Avarege requests in system: 2.2825115508683047 for servers number: 127
# Avarege requests in system: 2.247832402571897 for servers number: 128
# Avarege requests in system: 2.2080829889789806 for servers number: 129
# Avarege requests in system: 2.1386000678119106 for servers number: 130
# Avarege requests in system: 2.13290926974799 for servers number: 131
# Avarege requests in system: 2.08223164833863 for servers number: 132
# Avarege requests in system: 2.061097486080717 for servers number: 133
# Avarege requests in system: 2.030148146464361 for servers number: 134
# Avarege requests in system: 1.9959602622236157 for servers number: 135
# Avarege requests in system: 1.956277312204605 for servers number: 136
# Avarege requests in system: 1.9110882866147019 for servers number: 137
# Avarege requests in system: 1.9050687273599858 for servers number: 138
# Avarege requests in system: 1.837731361148592 for servers number: 139
# Avarege requests in system: 1.8355148362839757 for servers number: 140
# Avarege requests in system: 1.7891163214580013 for servers number: 141
# Avarege requests in system: 1.76803601108615 for servers number: 142
# Avarege requests in system: 1.7503151274841107 for servers number: 143
# Avarege requests in system: 1.712860714110961 for servers number: 144
# Avarege requests in system: 1.706074415833559 for servers number: 145
# Avarege requests in system: 1.6699770369001794 for servers number: 146
# Avarege requests in system: 1.6520677487581301 for servers number: 147
# Avarege requests in system: 1.6330511863752541 for servers number: 148
# Avarege requests in system: 1.6038584143859167 for servers number: 149
# Avarege requests in system: 1.5616355718572719 for servers number: 150
# Avarege requests in system: 1.563577965090937 for servers number: 151
# Avarege requests in system: 1.5316115302920028 for servers number: 152
# Avarege requests in system: 1.5187049258309806 for servers number: 153
# Avarege requests in system: 1.48489756370197 for servers number: 154
# Avarege requests in system: 1.4692525208517326 for servers number: 155
# Avarege requests in system: 1.4505510607754832 for servers number: 156
# Avarege requests in system: 1.4206299862447092 for servers number: 157
# Avarege requests in system: 1.4174402168409268 for servers number: 158
# Avarege requests in system: 1.389046823246873 for servers number: 159
# Avarege requests in system: 1.3791333374727632 for servers number: 160
# Avarege requests in system: 1.3590594422635502 for servers number: 161
# Avarege requests in system: 1.3592630799685752 for servers number: 162
# Avarege requests in system: 1.332798903630357 for servers number: 163
# Avarege requests in system: 1.32424670016348 for servers number: 164
# Avarege requests in system: 1.2969318279225541 for servers number: 165
# Avarege requests in system: 1.2843437446008743 for servers number: 166
# Avarege requests in system: 1.2622325227164126 for servers number: 167
# Avarege requests in system: 1.258082510330841 for servers number: 168
# Avarege requests in system: 1.2391559403760553 for servers number: 169
# Avarege requests in system: 1.2168082112962588 for servers number: 170
# Avarege requests in system: 1.2061690707557127 for servers number: 171
# Avarege requests in system: 1.1950698963255868 for servers number: 172
# Avarege requests in system: 1.1853530353762107 for servers number: 173
# Avarege requests in system: 1.1715591341137312 for servers number: 174
# Avarege requests in system: 1.1618817453347359 for servers number: 175
# Avarege requests in system: 1.1529359972659259 for servers number: 176
# Avarege requests in system: 1.1459627617948076 for servers number: 177
# Avarege requests in system: 1.1323946110668854 for servers number: 178
# Avarege requests in system: 1.1187683931202699 for servers number: 179
# Avarege requests in system: 1.101286516218982 for servers number: 180
# Avarege requests in system: 1.085988623365526 for servers number: 181
# Avarege requests in system: 1.0753772808395747 for servers number: 182
# Avarege requests in system: 1.0659155229888428 for servers number: 183
# Avarege requests in system: 1.0631537699759948 for servers number: 184
# Avarege requests in system: 1.0450076352256439 for servers number: 185
# Avarege requests in system: 1.0346980092656302 for servers number: 186
# Avarege requests in system: 1.0293831181622597 for servers number: 187
# Avarege requests in system: 1.0253268605741122 for servers number: 188
# Avarege requests in system: 1.0107514702535942 for servers number: 189
# Avarege requests in system: 1.0054710089033465 for servers number: 190
# Avarege requests in system: 0.9943131573829699 for servers number: 191
# Avarege requests in system: 0.9835102334068608 for servers number: 192
# Avarege requests in system: 0.981970073186945 for servers number: 193
# Avarege requests in system: 0.9651579663546033 for servers number: 194
# Avarege requests in system: 0.961361918922862 for servers number: 195
# Avarege requests in system: 0.9532762791503163 for servers number: 196
# Avarege requests in system: 0.9396177437805229 for servers number: 197
# Avarege requests in system: 0.9407144475601668 for servers number: 198
# Avarege requests in system: 0.9311505982843722 for servers number: 199
# Avarege requests in system: 0.9218428024555863 for servers number: 200

# %%
def little_law(lambda_val: float, requests_in_system, loss_probability: float):
    return requests_in_system / (lambda_val * (1 - loss_probability))

# %%
def normalize_values(data: NDArray[float]) -> NDArray[float]:
    min = np.min(data)
    max = np.max(data)

    return (data - min) / (max - min)

# %%
requests_in_system_list = np.load('./random/requests_in_system_list.npy')
loss_probabilities = np.load('./random/loss_probabilities.npy')

response_times = np.empty(len(requests_in_system_list))
for i in range(len(response_times)):
    lambda_val =  1 / 0.299
    response_times[i] = little_law(lambda_val, servers_num[i] * requests_in_system_list[i], loss_probabilities[i])

# %%
title = 'Среднее время отклика от количества серверов'
        
plt.ylabel('Среднее время отклика (мс)')
plt.xlabel('Количество серверов')
plt.title(title)

plt.plot(servers_num, response_times)

plt.show()

# %%
normalized_response_times = normalize_values(response_times)
normalized_servers_num = normalize_values(servers_num)

# %%
title = 'Среднее время отклика от количества серверов'
        
plt.ylabel('Отнормированное среднее время отклика (мс)')
plt.xlabel('Отнормированное количество серверов')
plt.title(title)

plt.plot(normalized_servers_num, normalized_response_times)

plt.show()

# %%
title = 'Вероятность потери требования от количества серверов'
        
plt.ylabel('Вероятность потери требования')
plt.xlabel('Отнормированное количество серверов')
plt.title(title)

plt.plot(normalized_servers_num, loss_probabilities)

plt.show()

# %%
def ideal_point_method(
    X: NDArray[float],
    Y: NDArray[float],
    Z: NDArray[float],
    ideal_point: (float, float, float)
) -> NDArray[float]:
    points_num = len(X)
    distances = np.empty(points_num, dtype=float)

    for i in range(points_num):
        distances[i] = np.sqrt((X[i] - ideal_point[0]) ** 2 + (Y[i] - ideal_point[1]) ** 2 + (Z[i] - ideal_point[2]) ** 2)

    return distances

def linear_convolution(
    X: NDArray[float],
    Y: NDArray[float],
    Z: NDArray[float],
    weights: (float, float, float)
) -> NDArray[float]:
    return weights[0] * X + weights[1] * Y + weights[2] * Z

# %%
ideal_point = (0, 0, 0)
ideal_point_method_result = ideal_point_method(normalized_servers_num, normalized_response_times, loss_probabilities, (0, 0, 0))

optimal_index = np.argmin(ideal_point_method_result)

optimal_number_of_servers = servers_num[optimal_index]
optimal_response_time = response_times[optimal_index]
optimal_loss_probability = loss_probabilities[optimal_index]

# %%
plt.title('Метод идеальной точки')

plt.ylabel('Значение целевой функции')
plt.xlabel('Количество серверов')

plt.plot(servers_num, ideal_point_method_result)

plt.show()

# %%
print(f'Оптимальное число серверов: {optimal_number_of_servers}')
print(f'Время отклика: {optimal_response_time}')
print(f'Вероятность потери заявки: {optimal_loss_probability}')
# Out:
# Оптимальное число серверов: 84
# Время отклика: 244.45572517106672
# Вероятность потери заявки: 0.29054264746926206

# %%
weights = (0.2, 0.5, 0.3)

linear_convolution_result = linear_convolution(normalized_servers_num, normalized_response_times, loss_probabilities, weights)

optimal_index = np.argmin(linear_convolution_result)
optimal_number_of_servers = servers_num[optimal_index]
optimal_loss_probability = loss_probabilities[optimal_index]

# %%
plt.title('Метод линейной свёртки критериев')

plt.ylabel('Значение целевой функции')
plt.xlabel('Количество серверов')

plt.plot(servers_num, linear_convolution_result)

plt.show()

# %%
print(f'Оптимальное число серверов: {optimal_number_of_servers}')
print(f'Среднее время отклика: {optimal_response_time}')
print(f'Вероятность потери заявки: {optimal_loss_probability}')
# Out:
# Оптимальное число серверов: 112
# Среднее время отклика: 244.45572517106672
# Вероятность потери заявки: 0.14632418844776338
