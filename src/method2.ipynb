# %%
from typing import Callable, Tuple

import numpy as np
import pandas as pd
from numba import prange, njit, typed, types
from tqdm.notebook import trange
from numpy.typing import NDArray
from numba import njit, prange
import matplotlib.pyplot as plt
from scipy import stats

from util import normalize_values, ideal_point_method, linear_convolution

# %%
def get_service_times() -> NDArray['float']:
    df = pd.read_csv('../data/service_times.csv')
    df.rename(columns={'TTI 0.95': 'service_time' }, inplace=True)
    df['service_time'] = df['service_time'].map(lambda time: float(time.replace('ms', '')))

    return np.array(df['service_time'])

# %%
service_times = get_service_times()

# %%
@njit
def arrive_cdf(n: int) -> float:
    return np.random.exponential(0.299 * n)
    
@njit
def leave_cdf() -> float:
    return np.random.exponential(510)

@njit
def departure_cdf() -> float:
    return np.random.choice(service_times) * 0.95 / 4

# %%
@njit
def get_next_event(
    arrival_time: float,
    request_times_queue: list,
    departure_time: float,
) -> (float, str, int):
    event_type = 'ARRIVAL'
    min_index = -1
    min_time = arrival_time

    if departure_time != -1 and departure_time < min_time:
        event_type = 'DEPARTURE'
        min_time = departure_time

    min_leave_time_index = -1
    min_leave_time = np.inf
    if len(request_times_queue) != 0:
        min_leave_time_index = np.argmin(request_times_queue)
    if min_leave_time_index != -1:
        min_leave_time = request_times_queue[min_leave_time_index]
        
    if min_leave_time < min_time:
        min_index = min_leave_time_index
        min_time = min_leave_time
        event_type = 'LEAVE'

    return min_time, event_type, min_index

# %%
@njit
def arrival(
    time: float,
    num_in_system: int,
    num_total_requests: int,
    leave_indicator: int,
    request_times_queue: list,
    departure_time: float,
    n: int,
    N: int,
) -> (float, int, int, int, list, float):
    num_in_system += 1 # увеличиваем число запросов в системе
    num_total_requests += 1

    if departure_time == -1: # если сервер свободен
        mu = departure_cdf()
        departure_time = time
        departure_time = time + mu # планируем обработку запроса
    else:
        if len(request_times_queue) == N:
            num_in_system -= 1 # считаем, что заявка покинула систему
            leave_indicator += 1 # увеличиваем индикатор выхода из системы
        else:
            gamma = leave_cdf()
            request_times_queue = np.append(request_times_queue, time + gamma)
    
    alpha = arrive_cdf(n)
    time += alpha
    return time, num_in_system, num_total_requests, leave_indicator, request_times_queue, departure_time

@njit
def departure(
    time: float,
    num_in_system: int,
    request_times_queue: list,
    departure_time: float,
) -> (int, list, list):
    num_in_system -= 1 # запрос обработан - уменьшаем число запросов в системе
    
    if (len(request_times_queue) == 0): # если очередь пуста
        departure_time = -1
    else:        
        gamma = departure_cdf()
        departure_time = time + gamma # планируем обработку запроса
        request_times_queue = np.delete(request_times_queue, 0)
    return num_in_system, request_times_queue, departure_time

@njit
def on_leave(
    time_index: float,
    num_in_system: int,
    leave_indicator: int,
    request_times_queue: list
) -> (int, int, list):
    num_in_system -= 1 # запрос ушёл - уменьшаем число запросов в системе
    leave_indicator += 1 # увеличиваем индикатор выхода из системы
    
    request_times_queue = np.delete(request_times_queue, time_index)

    return num_in_system, leave_indicator, request_times_queue

# %%
@njit
def update_area_num_in_system_stat(
    time: float,
    past_event_time: float,
    num_in_system: int,
    area_num_in_system: float
) -> (float, float):
    time_since_past_event = time - past_event_time
    past_event_time = time

    area_num_in_system += (num_in_system * time_since_past_event)
    return past_event_time, area_num_in_system

# %%
@njit
def num_in_system_iteration(
    T: float,
    n: int,
    N: int,
    return_value: str = 'average_requests_in_system'
) -> float:
    time = 0.0
    past_event_time = 0.0

    num_in_system = 0
    area_num_in_system: float = 0.0

    num_total_requests = 0
    leave_indicator = 0
    
    arrival_time = arrive_cdf(n)
    leave = leave_cdf()

    departure_time = -1
    request_times_queue = np.empty(0, dtype=np.float64)
    
    while time < T:
        time, event_type, time_index = get_next_event(arrival_time, request_times_queue, departure_time)
        past_event_time, area_num_in_system = update_area_num_in_system_stat(
            time,
            past_event_time,
            num_in_system,
            area_num_in_system
        )
        
        if event_type == 'ARRIVAL':
            arrival_time, num_in_system, num_total_requests, leave_indicator, request_times_queue, departure_time = arrival(
                time,
                num_in_system,
                num_total_requests,
                leave_indicator,
                request_times_queue,
                departure_time,
                n,
                N
            )
        elif event_type == 'DEPARTURE':
            num_in_system, request_times_queue, departure_time = departure(
                time,
                num_in_system,
                request_times_queue,
                departure_time
            )
        else:
            num_in_system, leave_indicator, request_times_queue = on_leave(
                time_index,
                num_in_system,
                leave_indicator,
                request_times_queue
            )

    average_requests_in_system = area_num_in_system / time
    loss_probability = leave_indicator / num_total_requests

    if return_value == 'average_requests_in_system':
        return average_requests_in_system
    if return_value == 'loss_probability':
        return loss_probability

# %%
@njit(parallel=True)
def num_in_system_iteration_resolver(
    T: float,
    N: int,
    n: int,
    max_queue_size: int,
    x_betta: float,
    eps: float = 1e-3,
    return_value: str = 'average_requests_in_system'
) -> float:
    N_new = N
    N_old = 0

    sum_data = 0
    sum_data_sq = 0
    while True: 
        for i in prange(N - N_old):
            value = num_in_system_iteration(T, n, max_queue_size, return_value)
            sum_data += value
            sum_data_sq += value ** 2
        E = sum_data / N
        D = (sum_data_sq / N) - (E ** 2)
        N_new = int(((x_betta ** 2) * D) / (eps ** 2))

        if N_new <= N:
            return E
        N_old = N
        N = N_new
        
        print(f'New N: {N}, old N: {N_old}')

# %%
MAX_SERVERS = 200
MIN_SERVERS = 1

T = 10000
iterations = 1000
max_queue_size = 100
betta = 0.95
x_betta = stats.norm.ppf(betta)

servers_num = np.arange(MIN_SERVERS, MAX_SERVERS + 1)

# %%
MAX_SERVERS = 200
MIN_SERVERS = 1

loss_probabilities = np.empty(0)

eps = 1e-3

for i in trange(MIN_SERVERS, MAX_SERVERS + 1):    
    loss_probability = num_in_system_iteration_resolver(
        T,
        iterations,
        i,
        max_queue_size,
        x_betta=x_betta,
        eps=eps,
        return_value = 'loss_probability'
    )
    print(f'Probability of loss: {loss_probability} for servers number: {i}')
    loss_probabilities = np.append(loss_probabilities, loss_probability)

with open('./random/loss_probabilities.npy', 'wb') as f:
    np.save(f, loss_probabilities)
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
#
# Probability of loss: 0.15078010413054574 for servers number: 111
# New N: 2008, old N: 1000
# New N: 2011, old N: 2008
# Probability of loss: 0.14775366715999672 for servers number: 112
# New N: 2029, old N: 1000
# Probability of loss: 0.14426686409779305 for servers number: 113
# New N: 1844, old N: 1000
# New N: 1925, old N: 1844
# Probability of loss: 0.14135188753041422 for servers number: 114
# New N: 1905, old N: 1000
# Probability of loss: 0.13907952646716157 for servers number: 115
# New N: 1806, old N: 1000
# Probability of loss: 0.13634446847254716 for servers number: 116
# New N: 1706, old N: 1000
# Probability of loss: 0.1326368024099765 for servers number: 117
# New N: 1750, old N: 1000
# Probability of loss: 0.12856116958669395 for servers number: 118
# New N: 1644, old N: 1000
# Probability of loss: 0.1258434433596313 for servers number: 119
# New N: 1569, old N: 1000
# New N: 1668, old N: 1569
# New N: 1690, old N: 1668
# Probability of loss: 0.12511440969586365 for servers number: 120
# New N: 1761, old N: 1000
# Probability of loss: 0.12087784775551524 for servers number: 121
# New N: 1607, old N: 1000
# New N: 1636, old N: 1607
# Probability of loss: 0.11906030174074904 for servers number: 122
# New N: 1518, old N: 1000
# New N: 1546, old N: 1518
# New N: 1549, old N: 1546
# Probability of loss: 0.11670085945297294 for servers number: 123
# New N: 1502, old N: 1000
# New N: 1507, old N: 1502
# New N: 1508, old N: 1507
# Probability of loss: 0.11368660446754997 for servers number: 124
# New N: 1367, old N: 1000
# New N: 1411, old N: 1367
# Probability of loss: 0.11218067315368851 for servers number: 125
# New N: 1361, old N: 1000
# New N: 1418, old N: 1361
# New N: 1459, old N: 1418
# Probability of loss: 0.11023135867476849 for servers number: 126
# New N: 1443, old N: 1000
# Probability of loss: 0.10778984092260574 for servers number: 127
# New N: 1454, old N: 1000
# Probability of loss: 0.10708973711857064 for servers number: 128
# New N: 1490, old N: 1000
# Probability of loss: 0.10452018380510326 for servers number: 129
# New N: 1403, old N: 1000
# New N: 1424, old N: 1403
# Probability of loss: 0.1015689382770504 for servers number: 130
# New N: 1447, old N: 1000
# Probability of loss: 0.10029010305819087 for servers number: 131
# New N: 1337, old N: 1000
# Probability of loss: 0.09752104299074908 for servers number: 132
# New N: 1329, old N: 1000
# New N: 1351, old N: 1329
# Probability of loss: 0.09674644730913327 for servers number: 133
# New N: 1337, old N: 1000
# New N: 1356, old N: 1337
# Probability of loss: 0.09427650116241718 for servers number: 134
# New N: 1299, old N: 1000
# New N: 1312, old N: 1299
# Probability of loss: 0.09209378524336251 for servers number: 135
# New N: 1221, old N: 1000
# New N: 1265, old N: 1221
# Probability of loss: 0.0924133734373365 for servers number: 136
# New N: 1212, old N: 1000
# New N: 1234, old N: 1212
# New N: 1236, old N: 1234
# New N: 1237, old N: 1236
# Probability of loss: 0.09032372941246558 for servers number: 137
# New N: 1195, old N: 1000
# Probability of loss: 0.08803931295451173 for servers number: 138
# New N: 1116, old N: 1000
# New N: 1127, old N: 1116
# New N: 1134, old N: 1127
# Probability of loss: 0.04630413731482442 for servers number: 188
# Probability of loss: 0.04506139733239655 for servers number: 189
# Probability of loss: 0.044909805172573564 for servers number: 190
# Probability of loss: 0.044375386062477554 for servers number: 191
# Probability of loss: 0.04430089370101757 for servers number: 192
# Probability of loss: 0.04244822484507607 for servers number: 193
# Probability of loss: 0.04280875221320142 for servers number: 194
# Probability of loss: 0.04217519274105542 for servers number: 195
# Probability of loss: 0.04261718819385305 for servers number: 196
# Probability of loss: 0.04132083565612995 for servers number: 197
# Probability of loss: 0.04079920200337616 for servers number: 198
# Probability of loss: 0.04021827146818623 for servers number: 199
# Probability of loss: 0.041004462367318376 for servers number: 200

# %%
requests_in_system_list = np.empty(0)

eps = 1e-0

for i in trange(MIN_SERVERS, MAX_SERVERS + 1):    
    avarege_requests_in_system = num_in_system_iteration_resolver(
        T,
        iterations,
        i,
        max_queue_size,
        x_betta=x_betta,
        eps=eps,
        return_value = 'average_requests_in_system'
    )
    print(f'Avarege requests in system: {avarege_requests_in_system} for servers number: {i}')
    requests_in_system_list = np.append(requests_in_system_list, avarege_requests_in_system)

with open('./random/requests_in_system_list.npy', 'wb') as f:
    np.save(f, requests_in_system_list)
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
# Avarege requests in system: 100.77086363158753 for servers number: 1
# Avarege requests in system: 100.52238474654142 for servers number: 2
# Avarege requests in system: 100.25333153144128 for servers number: 3
# Avarege requests in system: 99.95883370574846 for servers number: 4
# Avarege requests in system: 99.61707668019353 for servers number: 5
# Avarege requests in system: 99.24515922138819 for servers number: 6
# Avarege requests in system: 98.83457478389398 for servers number: 7
# Avarege requests in system: 98.34543785442287 for servers number: 8
# Avarege requests in system: 97.77224690926651 for servers number: 9
# Avarege requests in system: 97.05704824313989 for servers number: 10
# Avarege requests in system: 96.22613858580948 for servers number: 11
# Avarege requests in system: 95.11439844850999 for servers number: 12
# Avarege requests in system: 93.6853490667374 for servers number: 13
# Avarege requests in system: 91.75485516505118 for servers number: 14
# Avarege requests in system: 89.14047128752604 for servers number: 15
# Avarege requests in system: 85.73513138345065 for servers number: 16
# Avarege requests in system: 81.54687706147735 for servers number: 17
# Avarege requests in system: 77.04718669284584 for servers number: 18
# Avarege requests in system: 72.49985094305873 for servers number: 19
# Avarege requests in system: 68.45532190778304 for servers number: 20
# Avarege requests in system: 64.50913879033187 for servers number: 21
# Avarege requests in system: 61.14153398436745 for servers number: 22
# Avarege requests in system: 57.94338959102587 for servers number: 23
# Avarege requests in system: 54.882738670748836 for servers number: 24
# Avarege requests in system: 52.16935613856554 for servers number: 25
# Avarege requests in system: 49.74931025001711 for servers number: 26
# Avarege requests in system: 47.39760532074094 for servers number: 27
# Avarege requests in system: 45.31916303122886 for servers number: 28
# Avarege requests in system: 43.156356720728496 for servers number: 29
# Avarege requests in system: 41.52288474985331 for servers number: 30
# Avarege requests in system: 39.829340049250085 for servers number: 31
# Avarege requests in system: 37.974440304707464 for servers number: 32
# Avarege requests in system: 36.58485483314331 for servers number: 33
# Avarege requests in system: 35.13454228027233 for servers number: 34
# Avarege requests in system: 33.69251583933542 for servers number: 35
# Avarege requests in system: 32.445214163739685 for servers number: 36
# Avarege requests in system: 31.181226240659527 for servers number: 37
# Avarege requests in system: 29.97194796621499 for servers number: 38
# Avarege requests in system: 29.01341520561053 for servers number: 39
# Avarege requests in system: 27.938636757740436 for servers number: 40
# Avarege requests in system: 26.88995231437482 for servers number: 41
# Avarege requests in system: 26.010446345793195 for servers number: 42
# Avarege requests in system: 25.006026607332057 for servers number: 43
# Avarege requests in system: 24.305717780425603 for servers number: 44
# Avarege requests in system: 23.488300184899213 for servers number: 45
# Avarege requests in system: 22.583897190587827 for servers number: 46
# Avarege requests in system: 21.887475808383304 for servers number: 47
# Avarege requests in system: 21.145689972697742 for servers number: 48
# Avarege requests in system: 20.5182599449632 for servers number: 49
# Avarege requests in system: 19.714775468964053 for servers number: 50
# Avarege requests in system: 19.24188522535537 for servers number: 51
# Avarege requests in system: 18.550812468452744 for servers number: 52
# Avarege requests in system: 18.130228145920672 for servers number: 53
# Avarege requests in system: 17.5356640316418 for servers number: 54
# Avarege requests in system: 16.859678333135307 for servers number: 55
# Avarege requests in system: 16.37152249012994 for servers number: 56
# Avarege requests in system: 15.970385443013914 for servers number: 57
# Avarege requests in system: 15.421599333161407 for servers number: 58
# Avarege requests in system: 14.998489738301654 for servers number: 59
# Avarege requests in system: 14.462248949290247 for servers number: 60
# Avarege requests in system: 14.107919128377667 for servers number: 61
# Avarege requests in system: 13.630206654905502 for servers number: 62
# Avarege requests in system: 13.198037734466226 for servers number: 63
# Avarege requests in system: 12.737833851938483 for servers number: 64
# Avarege requests in system: 12.37983525153272 for servers number: 65
# Avarege requests in system: 12.051759141888983 for servers number: 66
# Avarege requests in system: 11.620476985514992 for servers number: 67
# Avarege requests in system: 11.213471623953568 for servers number: 68
# Avarege requests in system: 10.96770313106657 for servers number: 69
# Avarege requests in system: 10.703795090652712 for servers number: 70
# Avarege requests in system: 10.246794514680639 for servers number: 71
# Avarege requests in system: 9.916355932643842 for servers number: 72
# Avarege requests in system: 9.727816822107505 for servers number: 73
# Avarege requests in system: 9.410500603102522 for servers number: 74
# Avarege requests in system: 9.134895689494181 for servers number: 75
# Avarege requests in system: 8.795186416950054 for servers number: 76
# Avarege requests in system: 8.575613861906096 for servers number: 77
# Avarege requests in system: 8.349998488513359 for servers number: 78
# Avarege requests in system: 8.04647918677169 for servers number: 79
# Avarege requests in system: 7.842010880336803 for servers number: 80
# Avarege requests in system: 7.574878650370158 for servers number: 81
# Avarege requests in system: 7.355415178330931 for servers number: 82
# Avarege requests in system: 7.072300797759222 for servers number: 83
# Avarege requests in system: 6.982447326894301 for servers number: 84
# Avarege requests in system: 6.706871515644948 for servers number: 85
# Avarege requests in system: 6.557756573108645 for servers number: 86
# Avarege requests in system: 6.308321706437102 for servers number: 87
# Avarege requests in system: 6.143863095517193 for servers number: 88
# Avarege requests in system: 5.931012298422866 for servers number: 89
# Avarege requests in system: 5.837624618936716 for servers number: 90
# Avarege requests in system: 5.596597483603016 for servers number: 91
# Avarege requests in system: 5.485096384918493 for servers number: 92
# Avarege requests in system: 5.265945534752636 for servers number: 93
# Avarege requests in system: 5.098555773204781 for servers number: 94
# Avarege requests in system: 5.008093899250453 for servers number: 95
# Avarege requests in system: 4.837466380266012 for servers number: 96
# Avarege requests in system: 4.698268065500496 for servers number: 97
# Avarege requests in system: 4.600907894053067 for servers number: 98
# Avarege requests in system: 4.4104755089046845 for servers number: 99
# Avarege requests in system: 4.302694898530429 for servers number: 100
# Avarege requests in system: 4.222593290950317 for servers number: 101
# Avarege requests in system: 4.083973497331144 for servers number: 102
# Avarege requests in system: 3.97928759162751 for servers number: 103
# Avarege requests in system: 3.902752271687837 for servers number: 104
# Avarege requests in system: 3.7283589585876484 for servers number: 105
# Avarege requests in system: 3.6967073436434443 for servers number: 106
# Avarege requests in system: 3.575644993579252 for servers number: 107
# Avarege requests in system: 3.483071643761167 for servers number: 108
# Avarege requests in system: 3.403997548325518 for servers number: 109
# Avarege requests in system: 3.322101504401425 for servers number: 110
# Avarege requests in system: 3.236625608655422 for servers number: 111
# Avarege requests in system: 3.155737924907846 for servers number: 112
# Avarege requests in system: 3.067446708581886 for servers number: 113
# Avarege requests in system: 3.0273008060326236 for servers number: 114
# Avarege requests in system: 2.9338389496213853 for servers number: 115
# Avarege requests in system: 2.92837058803487 for servers number: 116
# Avarege requests in system: 2.830986503375527 for servers number: 117
# Avarege requests in system: 2.765325131263512 for servers number: 118
# Avarege requests in system: 2.6855591842214026 for servers number: 119
# Avarege requests in system: 2.6412892608086214 for servers number: 120
# Avarege requests in system: 2.581636035720868 for servers number: 121
# Avarege requests in system: 2.5286962149008403 for servers number: 122
# Avarege requests in system: 2.4848613135650317 for servers number: 123
# Avarege requests in system: 2.4293817720789948 for servers number: 124
# Avarege requests in system: 2.3865986169039157 for servers number: 125
# Avarege requests in system: 2.348307253891308 for servers number: 126
# Avarege requests in system: 2.29036506560342 for servers number: 127
# Avarege requests in system: 2.238725714982172 for servers number: 128
# Avarege requests in system: 2.211972849677008 for servers number: 129
# Avarege requests in system: 2.1607402092267605 for servers number: 130
# Avarege requests in system: 2.1163762326626054 for servers number: 131
# Avarege requests in system: 2.0883568740116667 for servers number: 132
# Avarege requests in system: 2.0619482008805914 for servers number: 133
# Avarege requests in system: 2.01547962129465 for servers number: 134
# Avarege requests in system: 1.9962647922062906 for servers number: 135
# Avarege requests in system: 1.9619803862061147 for servers number: 136
# Avarege requests in system: 1.9212976358959122 for servers number: 137
# Avarege requests in system: 1.901440348787441 for servers number: 138
# Avarege requests in system: 1.8582490691847717 for servers number: 139
# Avarege requests in system: 1.830300003553106 for servers number: 140
# Avarege requests in system: 1.7987719301878022 for servers number: 141
# Avarege requests in system: 1.7598412326162816 for servers number: 142
# Avarege requests in system: 1.7433288001549094 for servers number: 143
# Avarege requests in system: 1.7108903303237195 for servers number: 144
# Avarege requests in system: 1.679760581932646 for servers number: 145
# Avarege requests in system: 1.6909944448401237 for servers number: 146
# Avarege requests in system: 1.6385885821430923 for servers number: 147
# Avarege requests in system: 1.6348101924574723 for servers number: 148
# Avarege requests in system: 1.588989403723165 for servers number: 149
# Avarege requests in system: 1.5774404774680788 for servers number: 150
# Avarege requests in system: 1.5697702091518102 for servers number: 151
# Avarege requests in system: 1.5301721539563424 for servers number: 152
# Avarege requests in system: 1.5106776113127718 for servers number: 153
# Avarege requests in system: 1.474065779574802 for servers number: 154
# Avarege requests in system: 1.463821585255242 for servers number: 155
# Avarege requests in system: 1.4644376797208059 for servers number: 156
# Avarege requests in system: 1.4347392154554928 for servers number: 157
# Avarege requests in system: 1.4108502610427813 for servers number: 158
# Avarege requests in system: 1.3859705324377412 for servers number: 159
# Avarege requests in system: 1.3729482378258875 for servers number: 160
# Avarege requests in system: 1.3597599838974594 for servers number: 161
# Avarege requests in system: 1.3361213859304597 for servers number: 162
# Avarege requests in system: 1.3310251864954556 for servers number: 163
# Avarege requests in system: 1.3085460672332034 for servers number: 164
# Avarege requests in system: 1.2873156721187666 for servers number: 165
# Avarege requests in system: 1.2804626588929655 for servers number: 166
# Avarege requests in system: 1.264758664945378 for servers number: 167
# Avarege requests in system: 1.24382512886911 for servers number: 168
# Avarege requests in system: 1.2422035558313382 for servers number: 169
# Avarege requests in system: 1.215698662652007 for servers number: 170
# Avarege requests in system: 1.2054573661519439 for servers number: 171
# Avarege requests in system: 1.200984333815526 for servers number: 172
# Avarege requests in system: 1.179330235386308 for servers number: 173
# Avarege requests in system: 1.1763023242464514 for servers number: 174
# Avarege requests in system: 1.1771035267980996 for servers number: 175
# Avarege requests in system: 1.145551087445859 for servers number: 176
# Avarege requests in system: 1.1306466870816747 for servers number: 177
# Avarege requests in system: 1.1207712931759257 for servers number: 178
# Avarege requests in system: 1.1165643182154144 for servers number: 179
# Avarege requests in system: 1.1086443360395284 for servers number: 180
# Avarege requests in system: 1.101095853259302 for servers number: 181
# Avarege requests in system: 1.0976994984859878 for servers number: 182
# Avarege requests in system: 1.0733619179628318 for servers number: 183
# Avarege requests in system: 1.0703901824003923 for servers number: 184
# Avarege requests in system: 1.0481468030164587 for servers number: 185
# Avarege requests in system: 1.0552809611313594 for servers number: 186
# Avarege requests in system: 1.034216155703384 for servers number: 187
# Avarege requests in system: 1.02686397833695 for servers number: 188
# Avarege requests in system: 1.003874904685453 for servers number: 189
# Avarege requests in system: 1.00234411911787 for servers number: 190
# Avarege requests in system: 0.9999546354109523 for servers number: 191
# Avarege requests in system: 0.9947767854891925 for servers number: 192
# Avarege requests in system: 0.9797166934727348 for servers number: 193
# Avarege requests in system: 0.9718188174825518 for servers number: 194
# Avarege requests in system: 0.9692261255516149 for servers number: 195
# Avarege requests in system: 0.9534864702483118 for servers number: 196
# Avarege requests in system: 0.9431058305882122 for servers number: 197
# Avarege requests in system: 0.9379640447896043 for servers number: 198
# Avarege requests in system: 0.9236420288510695 for servers number: 199
# Avarege requests in system: 0.9228436578566231 for servers number: 200

# %%
def little_law(lambda_val: float, requests_in_system, loss_probability: float):
    return requests_in_system / (lambda_val * (1 - loss_probability))

# %%
requests_in_system_list = np.load('./random/requests_in_system_list.npy')
loss_probabilities = np.load('./random/loss_probabilities.npy')

response_times = np.empty(len(requests_in_system_list))
for i in range(len(response_times)):
    lambda_val =  1 / 0.299
    response_times[i] = little_law(lambda_val / servers_num[i], requests_in_system_list[i], loss_probabilities[i])

# %%
title = 'Среднее время отклика от количества серверов'
        
plt.ylabel('Среднее время отклика (мс)')
plt.xlabel('Количество серверов')
plt.title(title)

plt.plot(servers_num, response_times)

plt.show()

# %%
normalized_response_times = normalize_values(response_times)
normalized_servers_num = normalize_values(servers_num)

# %%
title = 'Среднее время отклика от количества серверов'
        
plt.ylabel('Отнормированное среднее время отклика (мс)')
plt.xlabel('Отнормированное количество серверов')
plt.title(title)

plt.plot(normalized_servers_num, normalized_response_times)

plt.show()

# %%
title = 'Вероятность потери требования от количества серверов'
        
plt.ylabel('Вероятность потери требования')
plt.xlabel('Отнормированное количество серверов')
plt.title(title)

plt.plot(normalized_servers_num, loss_probabilities)

plt.show()

# %%
ideal_point = (0, 0, 0)
ideal_point_method_result = ideal_point_method(normalized_servers_num, normalized_response_times, loss_probabilities, (0, 0, 0))

optimal_index = np.argmin(ideal_point_method_result)

optimal_number_of_servers = servers_num[optimal_index]
optimal_response_time = response_times[optimal_index]
optimal_loss_probability = loss_probabilities[optimal_index]

# %%
plt.title('Метод идеальной точки')

plt.ylabel('Значение целевой функции')
plt.xlabel('Количество серверов')

plt.plot(servers_num, ideal_point_method_result)

plt.show()

# %%
print(f'Оптимальное число серверов: {optimal_number_of_servers}')
print(f'Время отклика: {optimal_response_time}')
print(f'Вероятность потери заявки: {optimal_loss_probability}')
# Out:
# Оптимальное число серверов: 83
# Время отклика: 249.70029658287564
# Вероятность потери заявки: 0.29710420331944754

# %%
weights = (0.1, 0.6, 0.3)

linear_convolution_result = linear_convolution(normalized_servers_num, normalized_response_times, loss_probabilities, weights)

optimal_index = np.argmin(linear_convolution_result)

optimal_number_of_servers = servers_num[optimal_index]
optimal_response_time = response_times[optimal_index]
optimal_loss_probability = loss_probabilities[optimal_index]

# %%
plt.title('Метод линейной свёртки критериев')

plt.ylabel('Значение целевой функции')
plt.xlabel('Количество серверов')

plt.plot(servers_num, linear_convolution_result)

plt.show()

# %%
print(f'Оптимальное число серверов: {optimal_number_of_servers}')
print(f'Среднее время отклика: {optimal_response_time}')
print(f'Вероятность потери заявки: {optimal_loss_probability}')
# Out:
# Оптимальное число серверов: 145
# Среднее время отклика: 78.97805900834936
# Вероятность потери заявки: 0.07789554536924136
