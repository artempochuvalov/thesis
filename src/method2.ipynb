# %%
from typing import Callable, Tuple

import numpy as np
import pandas as pd
from numba import prange, njit, typed, types
from tqdm.notebook import trange
from numpy.typing import NDArray
from numba import njit, prange
import matplotlib.pyplot as plt
from scipy import stats
from sklearn import preprocessing

# %%
def get_service_times() -> NDArray['float']:
    df = pd.read_csv('../data/service_times.csv')
    df.rename(columns={'TTI 0.95': 'service_time' }, inplace=True)
    df['service_time'] = df['service_time'].map(lambda time: float(time.replace('ms', '')))

    return np.array(df['service_time'])

# %%
service_times = get_service_times()

# %%
@njit
def arrive_cdf(n: int) -> float:
    return np.random.exponential(0.299 * n)
    
@njit
def leave_cdf() -> float:
    return np.random.exponential(510)

@njit
def departure_cdf() -> float:
    return np.random.choice(service_times) / 4

# %%
@njit
def get_next_event(
    arrival_time: float,
    request_times_queue: list,
    departure_time: float,
) -> (float, str, int):
    event_type = 'ARRIVAL'
    min_index = -1
    min_time = arrival_time

    if departure_time != -1 and departure_time < min_time:
        event_type = 'DEPARTURE'
        min_time = departure_time

    min_leave_time_index = -1
    min_leave_time = np.inf
    if len(request_times_queue) != 0:
        min_leave_time_index = np.argmin(request_times_queue)
    if min_leave_time_index != -1:
        min_leave_time = request_times_queue[min_leave_time_index]
        
    if min_leave_time < min_time:
        min_index = min_leave_time_index
        min_time = min_leave_time
        event_type = 'LEAVE'

    return min_time, event_type, min_index

# %%
@njit
def arrival(
    time: float,
    num_in_system: int,
    num_total_requests: int,
    leave_indicator: int,
    request_times_queue: list,
    departure_time: float,
    n: int,
    N: int,
) -> (float, int, int, int, list, float):
    num_in_system += 1 # увеличиваем число запросов в системе
    num_total_requests += 1

    if departure_time == -1: # если сервер свободен
        mu = departure_cdf()
        departure_time = time
        departure_time = time + mu # планируем обработку запроса
    else:
        if len(request_times_queue) == N:
            num_in_system -= 1 # считаем, что заявка покинула систему
            leave_indicator += 1 # увеличиваем индикатор выхода из системы
        else:
            gamma = leave_cdf()
            request_times_queue = np.append(request_times_queue, time + gamma)
    
    alpha = arrive_cdf(n)
    time += alpha
    return time, num_in_system, num_total_requests, leave_indicator, request_times_queue, departure_time

@njit
def departure(
    time: float,
    num_in_system: int,
    request_times_queue: list,
    departure_time: float,
) -> (int, list, list):
    num_in_system -= 1 # запрос обработан - уменьшаем число запросов в системе
    
    if (len(request_times_queue) == 0): # если очередь пуста
        departure_time = -1
    else:        
        gamma = departure_cdf()
        departure_time = time + gamma # планируем обработку запроса
        request_times_queue = np.delete(request_times_queue, 0)
    return num_in_system, request_times_queue, departure_time

@njit
def on_leave(
    time_index: float,
    num_in_system: int,
    leave_indicator: int,
    request_times_queue: list
) -> (int, int, list):
    num_in_system -= 1 # запрос ушёл - уменьшаем число запросов в системе
    leave_indicator += 1 # увеличиваем индикатор выхода из системы
    
    request_times_queue = np.delete(request_times_queue, time_index)

    return num_in_system, leave_indicator, request_times_queue

# %%
@njit
def update_area_num_in_system_stat(
    time: float,
    past_event_time: float,
    num_in_system: int,
    area_num_in_system: float
) -> (float, float):
    time_since_past_event = time - past_event_time
    past_event_time = time

    area_num_in_system += (num_in_system * time_since_past_event)
    return past_event_time, area_num_in_system

# %%
@njit
def num_in_system_iteration(
    T: float,
    n: int,
    N: int,
    return_value: str = 'average_requests_in_system'
) -> float:
    time = 0.0
    past_event_time = 0.0

    num_in_system = 0
    area_num_in_system: float = 0.0

    num_total_requests = 0
    leave_indicator = 0
    
    arrival_time = arrive_cdf(n)
    leave = leave_cdf()

    departure_time = -1
    request_times_queue = np.empty(0, dtype=np.float64)
    
    while time < T:
        time, event_type, time_index = get_next_event(arrival_time, request_times_queue, departure_time)
        past_event_time, area_num_in_system = update_area_num_in_system_stat(
            time,
            past_event_time,
            num_in_system,
            area_num_in_system
        )
        
        if event_type == 'ARRIVAL':
            arrival_time, num_in_system, num_total_requests, leave_indicator, request_times_queue, departure_time = arrival(
                time,
                num_in_system,
                num_total_requests,
                leave_indicator,
                request_times_queue,
                departure_time,
                n,
                N
            )
        elif event_type == 'DEPARTURE':
            num_in_system, request_times_queue, departure_time = departure(
                time,
                num_in_system,
                request_times_queue,
                departure_time
            )
        else:
            num_in_system, leave_indicator, request_times_queue = on_leave(
                time_index,
                num_in_system,
                leave_indicator,
                request_times_queue
            )

    average_requests_in_system = area_num_in_system / time
    loss_probability = leave_indicator / num_total_requests

    if return_value == 'average_requests_in_system':
        return average_requests_in_system
    if return_value == 'loss_probability':
        return loss_probability

# %%
@njit(parallel=True)
def num_in_system_iteration_resolver(
    T: float,
    N: int,
    n: int,
    max_queue_size: int,
    x_betta: float,
    eps: float = 1e-3,
    return_value: str = 'average_requests_in_system'
) -> float:
    N_new = N
    N_old = 0

    sum_data = 0
    sum_data_sq = 0
    while True: 
        for i in prange(N - N_old):
            value = num_in_system_iteration(T, n, max_queue_size, return_value)
            sum_data += value
            sum_data_sq += value ** 2
        E = sum_data / N
        D = (sum_data_sq / N) - (E ** 2)
        N_new = int(((x_betta ** 2) * D) / (eps ** 2))

        if N_new <= N:
            return E
        N_old = N
        N = N_new
        
        print(f'New N: {N}, old N: {N_old}')

# %%
MAX_SERVERS = 200
MIN_SERVERS = 1

servers_num = np.arange(MIN_SERVERS, MAX_SERVERS + 1)
loss_probabilities = np.empty(0)

T = 10000
iterations = 1000
max_queue_size = 10_000
eps = 1e-3
betta = 0.95
x_betta = stats.norm.ppf(betta)

for i in trange(MIN_SERVERS, MAX_SERVERS + 1):    
    loss_probability = num_in_system_iteration_resolver(
        T,
        iterations,
        i,
        max_queue_size,
        x_betta=x_betta,
        eps=eps,
        return_value = 'loss_probability'
    )
    print(f'Probability of loss: {loss_probability} for servers number: {i}')
    loss_probabilities = np.append(loss_probabilities, loss_probability)

with open('./random/loss_probabilities.npy', 'wb') as f:
    np.save(f, loss_probabilities)
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
# Probability of loss: 0.9415121559977476 for servers number: 1
# Probability of loss: 0.933929895269609 for servers number: 2
# Probability of loss: 0.9263983932525134 for servers number: 3
# Probability of loss: 0.9188712040352495 for servers number: 4
# Probability of loss: 0.9113063530488078 for servers number: 5
# Probability of loss: 0.9037484716712961 for servers number: 6
# Probability of loss: 0.8962172627360235 for servers number: 7
# Probability of loss: 0.8885462228083669 for servers number: 8
# Probability of loss: 0.8812453025727229 for servers number: 9
# Probability of loss: 0.8736581951289425 for servers number: 10
# Probability of loss: 0.8660840049908561 for servers number: 11
# Probability of loss: 0.8584009299790426 for servers number: 12
# Probability of loss: 0.8511470197757247 for servers number: 13
# Probability of loss: 0.8433565350887212 for servers number: 14
# Probability of loss: 0.8360888937275007 for servers number: 15
# Probability of loss: 0.8281922282492833 for servers number: 16
# Probability of loss: 0.8207180785906435 for servers number: 17
# Probability of loss: 0.8133354719735802 for servers number: 18
# Probability of loss: 0.8058386724702102 for servers number: 19
# Probability of loss: 0.7979674798359655 for servers number: 20
# Probability of loss: 0.7906175140272697 for servers number: 21
# Probability of loss: 0.7831019780369589 for servers number: 22
# Probability of loss: 0.7760452425170143 for servers number: 23
# Probability of loss: 0.7680199186838788 for servers number: 24
# Probability of loss: 0.7603871174240134 for servers number: 25
# Probability of loss: 0.7525825679654186 for servers number: 26
# Probability of loss: 0.7451578094040244 for servers number: 27
# Probability of loss: 0.7375131148960545 for servers number: 28
# Probability of loss: 0.7299747781352682 for servers number: 29
# Probability of loss: 0.7233586386418426 for servers number: 30
# Probability of loss: 0.7155020968402573 for servers number: 31
# Probability of loss: 0.7074622818057624 for servers number: 32
# Probability of loss: 0.6999977167654712 for servers number: 33
# Probability of loss: 0.6928277486156712 for servers number: 34
# Probability of loss: 0.6853077691346969 for servers number: 35
# Probability of loss: 0.6772059967358683 for servers number: 36
# Probability of loss: 0.6697765338591659 for servers number: 37
# Probability of loss: 0.6623793567905949 for servers number: 38
# Probability of loss: 0.655074622291015 for servers number: 39
# Probability of loss: 0.6473925814461632 for servers number: 40
# Probability of loss: 0.6394905256486119 for servers number: 41
# Probability of loss: 0.6328852067276008 for servers number: 42
# Probability of loss: 0.6243622636282503 for servers number: 43
# Probability of loss: 0.6172228229346245 for servers number: 44
# Probability of loss: 0.610419745215575 for servers number: 45
# Probability of loss: 0.6025698897891895 for servers number: 46
# Probability of loss: 0.5942144059345961 for servers number: 47
# Probability of loss: 0.5864839425532626 for servers number: 48
# Probability of loss: 0.5796038856105991 for servers number: 49
# Probability of loss: 0.5723436639193077 for servers number: 50
# Probability of loss: 0.5646514197178524 for servers number: 51
# Probability of loss: 0.5567301564689379 for servers number: 52
# Probability of loss: 0.5489080160703194 for servers number: 53
# Probability of loss: 0.5423326096421062 for servers number: 54
# Probability of loss: 0.5332355561387245 for servers number: 55
# New N: 1079, old N: 1000
# New N: 1089, old N: 1079
# Probability of loss: 0.5272159009553484 for servers number: 56
# New N: 1080, old N: 1000
# Probability of loss: 0.5187217555802525 for servers number: 57
# New N: 1109, old N: 1000
# Probability of loss: 0.5121839838202404 for servers number: 58
# New N: 1218, old N: 1000
# New N: 1227, old N: 1218
# Probability of loss: 0.5039904858726962 for servers number: 59
# New N: 1232, old N: 1000
# Probability of loss: 0.4968416873369597 for servers number: 60
# New N: 1301, old N: 1000
# New N: 1352, old N: 1301
# New N: 1357, old N: 1352
# New N: 1358, old N: 1357
# Probability of loss: 0.4884679714264065 for servers number: 61
# New N: 1337, old N: 1000
# New N: 1348, old N: 1337
# Probability of loss: 0.4817074282940131 for servers number: 62
# New N: 1463, old N: 1000
# Probability of loss: 0.47397156213412234 for servers number: 63
# New N: 1351, old N: 1000
# New N: 1425, old N: 1351
# New N: 1426, old N: 1425
# Probability of loss: 0.46660265810921764 for servers number: 64
# New N: 1495, old N: 1000
# New N: 1515, old N: 1495
# New N: 1539, old N: 1515
# Probability of loss: 0.4582023734283203 for servers number: 65
# New N: 1492, old N: 1000
# New N: 1523, old N: 1492
# Probability of loss: 0.4508602999521989 for servers number: 66
# New N: 1575, old N: 1000
# Probability of loss: 0.44434759398523704 for servers number: 67
# New N: 1698, old N: 1000
# Probability of loss: 0.43695540319068565 for servers number: 68
# New N: 1787, old N: 1000
# Probability of loss: 0.4295776520169185 for servers number: 69
# New N: 1814, old N: 1000
# New N: 1896, old N: 1814
# New N: 1898, old N: 1896
# Probability of loss: 0.4215801367411652 for servers number: 70
# New N: 1884, old N: 1000
# Probability of loss: 0.4154109433707768 for servers number: 71
# New N: 1927, old N: 1000
# Probability of loss: 0.4065670191774471 for servers number: 72
# New N: 2044, old N: 1000
# Probability of loss: 0.39976920867972965 for servers number: 73
# New N: 2079, old N: 1000
# Probability of loss: 0.39151491261156385 for servers number: 74
# New N: 2111, old N: 1000
# New N: 2135, old N: 2111
# Probability of loss: 0.3849486893184142 for servers number: 75
# New N: 2248, old N: 1000
# Probability of loss: 0.3771223565098182 for servers number: 76
# New N: 2222, old N: 1000
# Probability of loss: 0.3709018401683082 for servers number: 77
# New N: 2245, old N: 1000
# New N: 2284, old N: 2245
# New N: 2293, old N: 2284
# New N: 2297, old N: 2293
# New N: 2303, old N: 2297
# New N: 2306, old N: 2303
# Probability of loss: 0.3622524798610796 for servers number: 78
# New N: 2311, old N: 1000
# New N: 2374, old N: 2311
# New N: 2394, old N: 2374
# Probability of loss: 0.35539691797537115 for servers number: 79
# New N: 2395, old N: 1000
# New N: 2436, old N: 2395
# New N: 2437, old N: 2436
# New N: 2439, old N: 2437
# Probability of loss: 0.348723847743648 for servers number: 80
# New N: 2530, old N: 1000
# New N: 2607, old N: 2530
# Probability of loss: 0.3414091956270154 for servers number: 81
# New N: 2415, old N: 1000
# New N: 2443, old N: 2415
# Probability of loss: 0.3343930753272004 for servers number: 82
# New N: 2538, old N: 1000
# Probability of loss: 0.3274216335866979 for servers number: 83
# New N: 2566, old N: 1000
# Probability of loss: 0.32143799598102435 for servers number: 84
# New N: 2762, old N: 1000
# New N: 2766, old N: 2762
# Probability of loss: 0.3151637227822116 for servers number: 85
# New N: 2495, old N: 1000
# New N: 2699, old N: 2495
# New N: 2700, old N: 2699
# Probability of loss: 0.30766100781240235 for servers number: 86
# New N: 2679, old N: 1000
# New N: 2785, old N: 2679
# Probability of loss: 0.30031780687303267 for servers number: 87
# New N: 2576, old N: 1000
# New N: 2631, old N: 2576
# Probability of loss: 0.2948831349104513 for servers number: 88
# New N: 2814, old N: 1000
# Probability of loss: 0.28746563620959115 for servers number: 89
# New N: 2800, old N: 1000
# New N: 2850, old N: 2800
# Probability of loss: 0.2809140014943738 for servers number: 90
# New N: 2883, old N: 1000
# Probability of loss: 0.2748460410548701 for servers number: 91
# New N: 2846, old N: 1000
# Probability of loss: 0.2678040042926961 for servers number: 92
# New N: 3004, old N: 1000
# Probability of loss: 0.2635144493854111 for servers number: 93
# New N: 2693, old N: 1000
# New N: 2697, old N: 2693
# New N: 2698, old N: 2697
# Probability of loss: 0.25745045255283205 for servers number: 94
# New N: 2786, old N: 1000
# Probability of loss: 0.2511213451064877 for servers number: 95
# New N: 2930, old N: 1000
# Probability of loss: 0.24477828778468536 for servers number: 96
# New N: 2864, old N: 1000
# Probability of loss: 0.23974266101163183 for servers number: 97
# New N: 2588, old N: 1000
# New N: 2737, old N: 2588
# New N: 2747, old N: 2737
# Probability of loss: 0.23403243701275975 for servers number: 98
# New N: 2747, old N: 1000
# Probability of loss: 0.22951909454042133 for servers number: 99
# New N: 2712, old N: 1000
# Probability of loss: 0.22298642583999617 for servers number: 100
# New N: 2598, old N: 1000
# New N: 2669, old N: 2598
# Probability of loss: 0.21983476715401407 for servers number: 101
# New N: 2615, old N: 1000
# Probability of loss: 0.21304921278642505 for servers number: 102
# New N: 2467, old N: 1000
# New N: 2537, old N: 2467
# New N: 2542, old N: 2537
# Probability of loss: 0.20799885633332493 for servers number: 103
# New N: 2577, old N: 1000
# Probability of loss: 0.2028370027661206 for servers number: 104
# New N: 2342, old N: 1000
# New N: 2606, old N: 2342
# New N: 2614, old N: 2606
# Probability of loss: 0.1992148799605075 for servers number: 105
# New N: 2543, old N: 1000
# New N: 2545, old N: 2543
# Probability of loss: 0.19582700604218917 for servers number: 106
# New N: 2327, old N: 1000
# New N: 2431, old N: 2327
# New N: 2440, old N: 2431
# Probability of loss: 0.18969397854275707 for servers number: 107
# New N: 2318, old N: 1000
# New N: 2353, old N: 2318
# New N: 2370, old N: 2353
# Probability of loss: 0.18722088170494203 for servers number: 108
# New N: 2484, old N: 1000
# Probability of loss: 0.18220050886970854 for servers number: 109
# New N: 2395, old N: 1000
# Probability of loss: 0.17866333394918907 for servers number: 110
# New N: 2373, old N: 1000
# Probability of loss: 0.17422776124334294 for servers number: 111
# New N: 2259, old N: 1000
# Probability of loss: 0.17101952557902123 for servers number: 112
# New N: 2096, old N: 1000
# New N: 2163, old N: 2096
# Probability of loss: 0.16526714055857367 for servers number: 113
# New N: 2307, old N: 1000
# Probability of loss: 0.16304681022607492 for servers number: 114
# New N: 2107, old N: 1000
# New N: 2180, old N: 2107
# New N: 2187, old N: 2180
# New N: 2189, old N: 2187
# Probability of loss: 0.16044212280909353 for servers number: 115
# New N: 2158, old N: 1000
# Probability of loss: 0.15657633616956718 for servers number: 116
# New N: 2114, old N: 1000
# Probability of loss: 0.15311502418289613 for servers number: 117
# New N: 1851, old N: 1000
# Probability of loss: 0.15031447766023617 for servers number: 118
# New N: 1968, old N: 1000
# Probability of loss: 0.1467857284533087 for servers number: 119
# New N: 2014, old N: 1000
# Probability of loss: 0.14230353460619724 for servers number: 120
# New N: 2016, old N: 1000
# Probability of loss: 0.1405753544117578 for servers number: 121
# New N: 1844, old N: 1000
# New N: 1942, old N: 1844
# New N: 1944, old N: 1942
# New N: 1946, old N: 1944
# Probability of loss: 0.13761517090806707 for servers number: 122
# New N: 1815, old N: 1000
# Probability of loss: 0.13506379510110142 for servers number: 123
# New N: 1811, old N: 1000
# New N: 1821, old N: 1811
# Probability of loss: 0.1332735016682485 for servers number: 124
# New N: 1837, old N: 1000
# Probability of loss: 0.12986039376848854 for servers number: 125
# New N: 1855, old N: 1000
# Probability of loss: 0.12792654991250957 for servers number: 126
# New N: 1832, old N: 1000
# Probability of loss: 0.1270296180720286 for servers number: 127
# New N: 1691, old N: 1000
# New N: 1696, old N: 1691
# Probability of loss: 0.1227076069610011 for servers number: 128
# New N: 1718, old N: 1000
# Probability of loss: 0.12011654781751903 for servers number: 129
# New N: 1670, old N: 1000
# Probability of loss: 0.1181411725007966 for servers number: 130
# New N: 1525, old N: 1000
# New N: 1551, old N: 1525
# New N: 1553, old N: 1551
# Probability of loss: 0.11584521941758713 for servers number: 131
# New N: 1611, old N: 1000
# Probability of loss: 0.11314157378838542 for servers number: 132
# New N: 1563, old N: 1000
# Probability of loss: 0.11214255338427478 for servers number: 133
# New N: 1695, old N: 1000
# Probability of loss: 0.111160776563978 for servers number: 134
# New N: 1555, old N: 1000
# Probability of loss: 0.10860757387021053 for servers number: 135
# New N: 1471, old N: 1000
# New N: 1494, old N: 1471
# Probability of loss: 0.10608819406884694 for servers number: 136
# New N: 1510, old N: 1000
# Probability of loss: 0.10467735850731975 for servers number: 137
# New N: 1412, old N: 1000
# Probability of loss: 0.10233009566790371 for servers number: 138
# New N: 1341, old N: 1000
# New N: 1361, old N: 1341
# Probability of loss: 0.10084134509368427 for servers number: 139
# New N: 1483, old N: 1000
# Probability of loss: 0.09973033448291652 for servers number: 140
# New N: 1346, old N: 1000
# Probability of loss: 0.0976569571443565 for servers number: 141
# New N: 1380, old N: 1000
# Probability of loss: 0.09562626689430792 for servers number: 142
# New N: 1305, old N: 1000
# Probability of loss: 0.09391843400244876 for servers number: 143
# New N: 1276, old N: 1000
# New N: 1293, old N: 1276
# New N: 1295, old N: 1293
# Probability of loss: 0.09235368167814478 for servers number: 144
# New N: 1246, old N: 1000
# New N: 1274, old N: 1246
# New N: 1281, old N: 1274
# Probability of loss: 0.09145920209301156 for servers number: 145
# New N: 1197, old N: 1000
# Probability of loss: 0.08984129804590292 for servers number: 146
# New N: 1283, old N: 1000
# New N: 1294, old N: 1283
# New N: 1297, old N: 1294
# Probability of loss: 0.08919840077177708 for servers number: 147
# New N: 1301, old N: 1000
# Probability of loss: 0.08755285861556715 for servers number: 148
# New N: 1218, old N: 1000
# Probability of loss: 0.08484277369911403 for servers number: 149
# New N: 1198, old N: 1000
# Probability of loss: 0.08435996510350773 for servers number: 150
# New N: 1153, old N: 1000
# Probability of loss: 0.08368335815789145 for servers number: 151
# New N: 1142, old N: 1000
# New N: 1165, old N: 1142
# New N: 1169, old N: 1165
# Probability of loss: 0.08226246118397922 for servers number: 152
# New N: 1176, old N: 1000
# Probability of loss: 0.08109319296379547 for servers number: 153
# New N: 1066, old N: 1000
# Probability of loss: 0.07886494900953808 for servers number: 154
# New N: 1150, old N: 1000
# Probability of loss: 0.07862256796914219 for servers number: 155
# New N: 1166, old N: 1000
# Probability of loss: 0.07665545377460857 for servers number: 156
# Probability of loss: 0.07508499838792539 for servers number: 157
# New N: 1113, old N: 1000
# Probability of loss: 0.07565823953997663 for servers number: 158
# New N: 1085, old N: 1000
# New N: 1087, old N: 1085
# New N: 1090, old N: 1087
# Probability of loss: 0.0743355971829309 for servers number: 159
# New N: 1007, old N: 1000
# Probability of loss: 0.07296919518934265 for servers number: 160
# New N: 1005, old N: 1000
# Probability of loss: 0.0725227796485575 for servers number: 161
# New N: 1055, old N: 1000
# Probability of loss: 0.07238648430565332 for servers number: 162
# Probability of loss: 0.07081773093304991 for servers number: 163
# New N: 1074, old N: 1000
# Probability of loss: 0.0688097353142353 for servers number: 164
# New N: 1029, old N: 1000
# New N: 1034, old N: 1029
# New N: 1038, old N: 1034
# Probability of loss: 0.06888278989911929 for servers number: 165
# Probability of loss: 0.0668554605513859 for servers number: 166
# Probability of loss: 0.06680005190981829 for servers number: 167
# Probability of loss: 0.06594375733431047 for servers number: 168
# Probability of loss: 0.06499851968565983 for servers number: 169
# Probability of loss: 0.06608105584320016 for servers number: 170
# Probability of loss: 0.06413505960507808 for servers number: 171
# Probability of loss: 0.06257231752360248 for servers number: 172
# Probability of loss: 0.06176439472164037 for servers number: 173
# Probability of loss: 0.06143340966660485 for servers number: 174
# Probability of loss: 0.06045664766613378 for servers number: 175
# Probability of loss: 0.05939687243584641 for servers number: 176
# Probability of loss: 0.05824597574005695 for servers number: 177
# Probability of loss: 0.05961497480315612 for servers number: 178
# Probability of loss: 0.057740322297829855 for servers number: 179
# Probability of loss: 0.05724377437225027 for servers number: 180
# Probability of loss: 0.0562872696976321 for servers number: 181
# Probability of loss: 0.055948964749072974 for servers number: 182
# Probability of loss: 0.05569876587596517 for servers number: 183
# Probability of loss: 0.05429602685329178 for servers number: 184
# Probability of loss: 0.053038292076373034 for servers number: 185
# Probability of loss: 0.05430618117599115 for servers number: 186
# Probability of loss: 0.05300025818478566 for servers number: 187
# Probability of loss: 0.05226114501273929 for servers number: 188
# Probability of loss: 0.05221398126182199 for servers number: 189
# Probability of loss: 0.05113297166295978 for servers number: 190
# Probability of loss: 0.050771767378302565 for servers number: 191
# Probability of loss: 0.050033724492995896 for servers number: 192
# Probability of loss: 0.049524305834279886 for servers number: 193
# Probability of loss: 0.04933034829226909 for servers number: 194
# Probability of loss: 0.04905196144680067 for servers number: 195
# Probability of loss: 0.048888002166380014 for servers number: 196
# Probability of loss: 0.04738522452098586 for servers number: 197
# Probability of loss: 0.047296823333888384 for servers number: 198
# Probability of loss: 0.04751924946814813 for servers number: 199
# Probability of loss: 0.04697431776838062 for servers number: 200

# %%
MAX_SERVERS = 200
MIN_SERVERS = 1

servers_num = np.arange(MIN_SERVERS, MAX_SERVERS + 1)
requests_in_system_list = np.empty(0)

T = 10000
iterations = 1000
max_queue_size = 10_000
eps = 1e-0
betta = 0.95
x_betta = stats.norm.ppf(betta)

for i in trange(MIN_SERVERS, MAX_SERVERS + 1):    
    avarege_requests_in_system = num_in_system_iteration_resolver(
        T,
        iterations,
        i,
        max_queue_size,
        x_betta=x_betta,
        eps=eps,
        return_value = 'average_requests_in_system'
    )
    print(f'Avarege requests in system: {avarege_requests_in_system} for servers number: {i}')
    requests_in_system_list = np.append(requests_in_system_list, avarege_requests_in_system)

with open('./random/requests_in_system_list.npy', 'wb') as f:
    np.save(f, requests_in_system_list)
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
# Avarege requests in system: 1606.9141972030243 for servers number: 1
# Avarege requests in system: 798.1001528263218 for servers number: 2
# Avarege requests in system: 527.577517111188 for servers number: 3
# Avarege requests in system: 392.7522946431083 for servers number: 4
# Avarege requests in system: 311.3581879196504 for servers number: 5
# Avarege requests in system: 258.18489121700355 for servers number: 6
# Avarege requests in system: 219.18956161908932 for servers number: 7
# Avarege requests in system: 190.5553003851589 for servers number: 8
# Avarege requests in system: 167.958533161135 for servers number: 9
# Avarege requests in system: 149.9459986981525 for servers number: 10
# Avarege requests in system: 135.26240439189024 for servers number: 11
# Avarege requests in system: 122.98219815139132 for servers number: 12
# Avarege requests in system: 112.52401500883984 for servers number: 13
# Avarege requests in system: 103.53676937615197 for servers number: 14
# Avarege requests in system: 96.07661787725884 for servers number: 15
# Avarege requests in system: 89.37312753799027 for servers number: 16
# Avarege requests in system: 83.37699302345017 for servers number: 17
# Avarege requests in system: 77.98831499547443 for servers number: 18
# Avarege requests in system: 73.33482724346506 for servers number: 19
# Avarege requests in system: 69.19073694795865 for servers number: 20
# Avarege requests in system: 65.26839413366504 for servers number: 21
# Avarege requests in system: 61.51628861005409 for servers number: 22
# Avarege requests in system: 58.519968777403776 for servers number: 23
# Avarege requests in system: 55.613875283578494 for servers number: 24
# Avarege requests in system: 52.95030599677368 for servers number: 25
# Avarege requests in system: 50.3859173499416 for servers number: 26
# Avarege requests in system: 48.12322048454828 for servers number: 27
# Avarege requests in system: 45.961241965599285 for servers number: 28
# Avarege requests in system: 44.04772421171558 for servers number: 29
# Avarege requests in system: 42.19024681825933 for servers number: 30
# Avarege requests in system: 40.38008960352889 for servers number: 31
# Avarege requests in system: 38.64434499910503 for servers number: 32
# Avarege requests in system: 37.23940498960954 for servers number: 33
# Avarege requests in system: 35.81312396483643 for servers number: 34
# Avarege requests in system: 34.36008210631867 for servers number: 35
# Avarege requests in system: 32.99941321370215 for servers number: 36
# Avarege requests in system: 31.969459769258332 for servers number: 37
# Avarege requests in system: 30.66722412194975 for servers number: 38
# Avarege requests in system: 29.68898383875806 for servers number: 39
# Avarege requests in system: 28.55298600404134 for servers number: 40
# Avarege requests in system: 27.594854893614176 for servers number: 41
# Avarege requests in system: 26.686232202510567 for servers number: 42
# Avarege requests in system: 25.7542111221831 for servers number: 43
# Avarege requests in system: 24.934718606863765 for servers number: 44
# Avarege requests in system: 24.15256625359802 for servers number: 45
# Avarege requests in system: 23.394526821985234 for servers number: 46
# Avarege requests in system: 22.65362109028727 for servers number: 47
# Avarege requests in system: 21.903401381846745 for servers number: 48
# Avarege requests in system: 21.154913360817034 for servers number: 49
# Avarege requests in system: 20.522644445186152 for servers number: 50
# Avarege requests in system: 19.952689991603147 for servers number: 51
# Avarege requests in system: 19.270884531940926 for servers number: 52
# Avarege requests in system: 18.684845664266728 for servers number: 53
# Avarege requests in system: 18.0733877962401 for servers number: 54
# Avarege requests in system: 17.644076002154677 for servers number: 55
# Avarege requests in system: 17.10087987376831 for servers number: 56
# Avarege requests in system: 16.615181379949696 for servers number: 57
# Avarege requests in system: 16.05984885194641 for servers number: 58
# Avarege requests in system: 15.592280913353704 for servers number: 59
# Avarege requests in system: 15.12223335101874 for servers number: 60
# Avarege requests in system: 14.67562968282872 for servers number: 61
# Avarege requests in system: 14.259102585722964 for servers number: 62
# Avarege requests in system: 13.946012857904321 for servers number: 63
# Avarege requests in system: 13.39718376092055 for servers number: 64
# Avarege requests in system: 13.096524215407882 for servers number: 65
# Avarege requests in system: 12.684192623659177 for servers number: 66
# Avarege requests in system: 12.35005919168219 for servers number: 67
# Avarege requests in system: 11.99834948546552 for servers number: 68
# Avarege requests in system: 11.645714801120524 for servers number: 69
# Avarege requests in system: 11.31229317969935 for servers number: 70
# Avarege requests in system: 10.952589931851097 for servers number: 71
# Avarege requests in system: 10.65562251663516 for servers number: 72
# Avarege requests in system: 10.423941556280289 for servers number: 73
# Avarege requests in system: 10.07354369945004 for servers number: 74
# Avarege requests in system: 9.792708382606246 for servers number: 75
# Avarege requests in system: 9.49670337113782 for servers number: 76
# Avarege requests in system: 9.235610020732889 for servers number: 77
# Avarege requests in system: 8.923197920379152 for servers number: 78
# Avarege requests in system: 8.644642238806949 for servers number: 79
# Avarege requests in system: 8.475078174357584 for servers number: 80
# Avarege requests in system: 8.27018527562925 for servers number: 81
# Avarege requests in system: 7.962320219297139 for servers number: 82
# Avarege requests in system: 7.689777506759254 for servers number: 83
# Avarege requests in system: 7.521896920384347 for servers number: 84
# Avarege requests in system: 7.359196028866381 for servers number: 85
# Avarege requests in system: 7.120423097675999 for servers number: 86
# Avarege requests in system: 6.911011431057552 for servers number: 87
# Avarege requests in system: 6.66071757505502 for servers number: 88
# Avarege requests in system: 6.495746744563233 for servers number: 89
# Avarege requests in system: 6.353228028947056 for servers number: 90
# Avarege requests in system: 6.220699028871378 for servers number: 91
# Avarege requests in system: 5.970135440243874 for servers number: 92
# Avarege requests in system: 5.813080495074475 for servers number: 93
# Avarege requests in system: 5.67314106530999 for servers number: 94
# Avarege requests in system: 5.545716325200507 for servers number: 95
# Avarege requests in system: 5.398308254821129 for servers number: 96
# Avarege requests in system: 5.227240730782666 for servers number: 97
# Avarege requests in system: 5.066593050164385 for servers number: 98
# Avarege requests in system: 4.937706098921836 for servers number: 99
# Avarege requests in system: 4.790141137190479 for servers number: 100
# Avarege requests in system: 4.697353128867717 for servers number: 101
# Avarege requests in system: 4.576687793740235 for servers number: 102
# Avarege requests in system: 4.420924313228715 for servers number: 103
# Avarege requests in system: 4.315968281836852 for servers number: 104
# Avarege requests in system: 4.22383865511519 for servers number: 105
# Avarege requests in system: 4.085342516111252 for servers number: 106
# Avarege requests in system: 3.9822210745021858 for servers number: 107
# Avarege requests in system: 3.89231763576321 for servers number: 108
# Avarege requests in system: 3.802734743489953 for servers number: 109
# Avarege requests in system: 3.6853331412492008 for servers number: 110
# Avarege requests in system: 3.5893347117060626 for servers number: 111
# Avarege requests in system: 3.530994778448053 for servers number: 112
# Avarege requests in system: 3.4884764708374285 for servers number: 113
# Avarege requests in system: 3.394085914944799 for servers number: 114
# Avarege requests in system: 3.3340322652807997 for servers number: 115
# Avarege requests in system: 3.19848261801733 for servers number: 116
# Avarege requests in system: 3.1343862275880885 for servers number: 117
# Avarege requests in system: 3.085527870416628 for servers number: 118
# Avarege requests in system: 3.016685090171248 for servers number: 119
# Avarege requests in system: 2.9643258233856 for servers number: 120
# Avarege requests in system: 2.9042529196530857 for servers number: 121
# Avarege requests in system: 2.815555993376075 for servers number: 122
# Avarege requests in system: 2.7763130726361127 for servers number: 123
# Avarege requests in system: 2.696399122381815 for servers number: 124
# Avarege requests in system: 2.6508767740822137 for servers number: 125
# Avarege requests in system: 2.596016211075962 for servers number: 126
# Avarege requests in system: 2.5551259913771145 for servers number: 127
# Avarege requests in system: 2.498093023546461 for servers number: 128
# Avarege requests in system: 2.449795929353521 for servers number: 129
# Avarege requests in system: 2.4216412464487376 for servers number: 130
# Avarege requests in system: 2.3698195517222693 for servers number: 131
# Avarege requests in system: 2.3268485294005297 for servers number: 132
# Avarege requests in system: 2.277846971052311 for servers number: 133
# Avarege requests in system: 2.2532131064115006 for servers number: 134
# Avarege requests in system: 2.1857912009223006 for servers number: 135
# Avarege requests in system: 2.1620899260494433 for servers number: 136
# Avarege requests in system: 2.1373515089658732 for servers number: 137
# Avarege requests in system: 2.080123619673377 for servers number: 138
# Avarege requests in system: 2.051289272617657 for servers number: 139
# Avarege requests in system: 2.028132484788166 for servers number: 140
# Avarege requests in system: 1.9807880554154131 for servers number: 141
# Avarege requests in system: 1.9726171936596302 for servers number: 142
# Avarege requests in system: 1.9279389721285143 for servers number: 143
# Avarege requests in system: 1.9019442922033998 for servers number: 144
# Avarege requests in system: 1.8872118114961223 for servers number: 145
# Avarege requests in system: 1.8395160458289606 for servers number: 146
# Avarege requests in system: 1.8035215822170279 for servers number: 147
# Avarege requests in system: 1.8098152557332263 for servers number: 148
# Avarege requests in system: 1.7685575541478582 for servers number: 149
# Avarege requests in system: 1.7182279474594417 for servers number: 150
# Avarege requests in system: 1.705496457864101 for servers number: 151
# Avarege requests in system: 1.6829513953365196 for servers number: 152
# Avarege requests in system: 1.6571396447606725 for servers number: 153
# Avarege requests in system: 1.6336257385585848 for servers number: 154
# Avarege requests in system: 1.6202795646576689 for servers number: 155
# Avarege requests in system: 1.6016985155068932 for servers number: 156
# Avarege requests in system: 1.5770673218548654 for servers number: 157
# Avarege requests in system: 1.5360009455360706 for servers number: 158
# Avarege requests in system: 1.5267091260776295 for servers number: 159
# Avarege requests in system: 1.5172614961421778 for servers number: 160
# Avarege requests in system: 1.491436121809654 for servers number: 161
# Avarege requests in system: 1.478525225210124 for servers number: 162
# Avarege requests in system: 1.454066326706139 for servers number: 163
# Avarege requests in system: 1.4364600639515648 for servers number: 164
# Avarege requests in system: 1.4184620483108858 for servers number: 165
# Avarege requests in system: 1.3981450873552308 for servers number: 166
# Avarege requests in system: 1.4021311325911168 for servers number: 167
# Avarege requests in system: 1.369470579557665 for servers number: 168
# Avarege requests in system: 1.3604724905291268 for servers number: 169
# Avarege requests in system: 1.3403355323249924 for servers number: 170
# Avarege requests in system: 1.3272547981460168 for servers number: 171
# Avarege requests in system: 1.3124719022910771 for servers number: 172
# Avarege requests in system: 1.3035456781932435 for servers number: 173
# Avarege requests in system: 1.2818330413255692 for servers number: 174
# Avarege requests in system: 1.2607890685048364 for servers number: 175
# Avarege requests in system: 1.2531614866754102 for servers number: 176
# Avarege requests in system: 1.2372925909863781 for servers number: 177
# Avarege requests in system: 1.2277792785842283 for servers number: 178
# Avarege requests in system: 1.2016246675292486 for servers number: 179
# Avarege requests in system: 1.1986429300454353 for servers number: 180
# Avarege requests in system: 1.1859724155136597 for servers number: 181
# Avarege requests in system: 1.1793640451076772 for servers number: 182
# Avarege requests in system: 1.1655394204922027 for servers number: 183
# Avarege requests in system: 1.1467734851163538 for servers number: 184
# Avarege requests in system: 1.1368754196608302 for servers number: 185
# Avarege requests in system: 1.1287066665528944 for servers number: 186
# Avarege requests in system: 1.1186006327142353 for servers number: 187
# Avarege requests in system: 1.1135982330815286 for servers number: 188
# Avarege requests in system: 1.1058920578442837 for servers number: 189
# Avarege requests in system: 1.0922746559826915 for servers number: 190
# Avarege requests in system: 1.0802861288426433 for servers number: 191
# Avarege requests in system: 1.0716064642424552 for servers number: 192
# Avarege requests in system: 1.0564866345963708 for servers number: 193
# Avarege requests in system: 1.0482561523118537 for servers number: 194
# Avarege requests in system: 1.0427587427834788 for servers number: 195
# Avarege requests in system: 1.026445560339914 for servers number: 196
# Avarege requests in system: 1.0250685774535144 for servers number: 197
# Avarege requests in system: 1.0119846148049128 for servers number: 198
# Avarege requests in system: 1.0090455865683394 for servers number: 199
# Avarege requests in system: 1.0053230219088174 for servers number: 200

# %%
def little_law(lambda_val: float, requests_in_system, loss_probability: float):
    return requests_in_system / (lambda_val * (1 - loss_probability))

# %%
def normalize_values(data: NDArray[float]) -> NDArray[float]:
    min = np.min(data)
    max = np.max(data)

    return (data - min) / (max - min)

# %%
requests_in_system_list = np.load('./random/requests_in_system_list.npy')
loss_probabilities = np.load('./random/loss_probabilities.npy')

response_times = np.empty(len(requests_in_system_list))
for i in range(len(response_times)):
    lambda_val =  1 / 0.299
    response_times[i] = little_law(lambda_val, servers_num[i] * requests_in_system_list[i], loss_probabilities[i])

# %%
title = 'Среднее время отклика от количества серверов'
        
plt.ylabel('Среднее время отклика (мс)')
plt.xlabel('Количество серверов')
plt.title(title)

plt.plot(servers_num, response_times)

plt.show()

# %%
normalized_response_times = normalize_values(response_times)
normalized_servers_num = normalize_values(servers_num)

# %%
title = 'Среднее время отклика от количества серверов'
        
plt.ylabel('Отнормированное среднее время отклика (мс)')
plt.xlabel('Отнормированное количество серверов')
plt.title(title)

plt.plot(normalized_servers_num, normalized_response_times)

plt.show()

# %%
title = 'Вероятность потери требования от количества серверов'
        
plt.ylabel('Вероятность потери требования')
plt.xlabel('Отнормированное количество серверов')
plt.title(title)

plt.plot(normalized_servers_num, loss_probabilities)

plt.show()

# %%
def ideal_point_method(
    X: NDArray[float],
    Y: NDArray[float],
    Z: NDArray[float],
    ideal_point: (float, float, float)
) -> NDArray[float]:
    points_num = len(X)
    distances = np.empty(points_num, dtype=float)

    for i in range(points_num):
        distances[i] = np.sqrt((X[i] - ideal_point[0]) ** 2 + (Y[i] - ideal_point[1]) ** 2 + (Z[i] - ideal_point[2]) ** 2)

    return distances

def linear_convolution(
    X: NDArray[float],
    Y: NDArray[float],
    Z: NDArray[float],
    weights: (float, float, float)
) -> NDArray[float]:
    return weights[0] * X + weights[1] * Y + weights[2] * Z

# %%
ideal_point = (0, 0, 0)
ideal_point_method_result = ideal_point_method(normalized_servers_num, normalized_response_times, loss_probabilities, (0, 0, 0))

optimal_index = np.argmin(ideal_point_method_result)

optimal_number_of_servers = servers_num[optimal_index]
optimal_response_time = response_times[optimal_index]
optimal_loss_probability = loss_probabilities[optimal_index]

# %%
plt.title('Метод идеальной точки')

plt.ylabel('Значение целевой функции')
plt.xlabel('Количество серверов')

plt.plot(servers_num, ideal_point_method_result)

plt.show()

# %%
print(f'Оптимальное число серверов: {optimal_number_of_servers}')
print(f'Время отклика: {optimal_response_time}')
print(f'Вероятность потери заявки: {optimal_loss_probability}')
# Out:
# Оптимальное число серверов: 87
# Время отклика: 256.93971080306903
# Вероятность потери заявки: 0.30031780687303267

# %%
weights = (0.1, 0.5, 0.4)

linear_convolution_result = linear_convolution(normalized_servers_num, normalized_response_times, loss_probabilities, weights)

optimal_index = np.argmin(linear_convolution_result)
optimal_number_of_servers = servers_num[optimal_index]
optimal_loss_probability = loss_probabilities[optimal_index]

# %%
plt.title('Метод линейной свёртки критериев')

plt.ylabel('Значение целевой функции')
plt.xlabel('Количество серверов')

plt.plot(servers_num, linear_convolution_result)

plt.show()

# %%
print(f'Оптимальное число серверов: {optimal_number_of_servers}')
print(f'Среднее время отклика: {optimal_response_time}')
print(f'Вероятность потери заявки: {optimal_loss_probability}')
# Out:
# Оптимальное число серверов: 157
# Среднее время отклика: 256.93971080306903
# Вероятность потери заявки: 0.07508499838792539
